# %%
#!wget https://dumps.wikimedia.org/plwiki/20240801/plwiki-20240801-pages-meta-current1.xml-p1p187037.bz2
# Out:
# --2024-08-17 11:57:56--  https://dumps.wikimedia.org/plwiki/20240801/plwiki-20240801-pages-meta-current1.xml-p1p187037.bz2
# Resolving dumps.wikimedia.org (dumps.wikimedia.org)... 2620:0:861:3:208:80:154:71, 208.80.154.71
# Connecting to dumps.wikimedia.org (dumps.wikimedia.org)|2620:0:861:3:208:80:154:71|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 239025740 (228M) [application/octet-stream]
# Saving to: ‘plwiki-20240801-pages-meta-current1.xml-p1p187037.bz2’
#
# plwiki-20240801-pag 100%[===================>] 227.95M  4.57MB/s    in 52s
#
# 2024-08-17 11:58:49 (4.39 MB/s) - ‘plwiki-20240801-pages-meta-current1.xml-p1p187037.bz2’ saved [239025740/239025740]

# %%
FILENAMES = ['plwiki-20240801-pages-meta-current1.xml-p1p187037.bz2']

# %% [markdown]
# # Putting everything together

# %%
import re
import sys
import bz2
from xml import sax
import mwparserfromhell as mw
from collections import Counter

# %%
SEP_STR = ";;;"
SEP = mw.nodes.text.Text(SEP_STR)
re_URL = re.compile(r"(?:http|https|ftp)://[A-Za-z0-9:._\/~%+&#?!=()@-]+[\w/]")
re_SEP = re.compile(r";{3,}")

# %%
def strip_wikicode(text):
    t = mw.parse(text)
    for tag in t.filter_tags(matches=lambda node: node.tag == 'ref'):
        if hasattr(tag.contents, 'nodes'):
            tag.contents.nodes = [SEP] + tag.contents.nodes + [SEP]
        else:
            tag.value = SEP_STR + tag.value + SEP_STR
    text = re_URL.sub(SEP_STR, t.strip_code())
    text = re_SEP.sub("\n\n", text)
    return text

# %%
class WikipediaHandler(sax.handler.ContentHandler):
    in_page = False
    in_text = False
    last_text = ""

    def __init__(self, handle_text):
        self.handle_text = handle_text

    def startElement(self, name, attrs):
        if name == 'page':
            self.in_page = True
            self.in_text = False
        elif self.in_page and name == 'text':
            self.in_text = True
            self.last_text = ""
        else:
            self.in_text = False

    def endElement(self, name):
        if name == 'text':
            self.in_text = False
        elif name == 'page':
            self.in_text = False
            self.in_page = False
            self.parse_text()

    def characters(self, content):
        if self.in_text:
            self.last_text += content

    def parse_text(self):
        if self.last_text:
            text = strip_wikicode(self.last_text)
            self.last_text = ""
            self.handle_text(text)

# %%
def read_chunks(file_name, callback, chunk_size, max_chunks=None):
    if file_name.endswith(".bz2"):
        fd = bz2.open(file_name, "rt", encoding="utf-8")
    else:
        fd = open(file_name, "rt", encoding="utf-8")

    chunk_n = 0
    with fd:
        while max_chunks is None or chunk_n < max_chunks:
            buffer = fd.read(chunk_size)
            chunk_n += 1
            print("Chunk", chunk_n, "of", len(buffer), "bytes", type(buffer), file=sys.stderr)
            if not buffer:
                break
            try:
                callback(buffer)
            except StopIteration:
                break

# %%
class MultiDocumentParser:
    def __init__(self, callback, handler_class=WikipediaHandler):
        self.callback = callback
        self.handler = None
        self.handler_class = handler_class
        self.debug_context = ""
        self.parser = None

    def reset(self):
        print("New XML document - parser reset", file=sys.stderr)
        if self.handler is not None:
            self.handler.parse_text()
        self.parser = sax.make_parser()
        self.handler = self.handler_class(self.callback)
        self.parser.setContentHandler(self.handler)

    def feed(self, buffer):
        if self.parser is None:
            self.reset()
        while True:
            try:
                self.parser.feed(buffer)
            except sax.SAXParseException as e:
                i = self.parser._parser.CurrentByteIndex
                # not XML_ERROR_JUNK_AFTER_DOC_ELEMENT
                if e.getException().code != 9:
                    print("Exception context:", self.debug_context, "###", buffer[i-10:i], "###", buffer[i:i+10], file=sys.stderr)
                    raise
                buffer = buffer[i:]
                self.reset()
            else:
                break
        self.debug_context = buffer[-10:]

    def __enter__(self, *args, **kwargs):
        return self

    def __exit__(self, *args, **kwargs):
        if self.handler is not None:
            self.handler.parse_text()
        return self

# %%
def handle_article_text(text):
    print(len(text), repr([text[:10], text[-10:]]))

# %%
chunk_size = 1024 * 1024 * 8  # 8 MB
# chunk_size = 1024 * 1024 * 128  # 128 MB
parser = MultiDocumentParser(handle_article_text, WikipediaHandler)
for file_name in FILENAMES:
    read_chunks(file_name, parser.feed, chunk_size, 3)
# Out:
# Chunk 1 of 8388608 bytes <class 'str'>
# Parser reset
# 13604 ['AWK – inte', ' skryptowe']
# 491 ['Alergologi', ' lekarskie']
# 136 ['Andrzej To', 'as.--Kpjas']
# 14540 ['thumb|94 z', 'nia znaków']
# 47570 ['thumb|Atom', ' \n \n \n \n\n ']
# 8169 ['Aksjomat, ', 'a \n\n \n\n \n ']
# 6233 ['mały|Rycin', '05-10].\n\n ']
# 4461 ['Link\n\nPopr', '2 sty 2015']
# 3865 ['Alkeny – o', 'afia \n \n\n ']
# 2477 ['ActiveX – ', 't Explorer']
# 3736 ['Interfejs ', 'zypisy \n\n ']
# 5633 ['AmigaOS – ', 'operacyjne']
# 4793 ['Associatio', 'ozarządowe']
# 2964 ['Alternatyw', 'i logiczne']
# 2291 ['Aksjomat i', 'tematyczne']
# 23 ['PATRZ Cesa', 'wo Etiopii']
# 715 ['thumb|150p', 'ia:Polieny']
# 1433 ['thumb|200p', 'zypisy \n\n ']
# 9142 ['Alkany (pa', ' \n\n\n \n\n\n\n ']
# 4869 ['thumb|140p', 'zypisy \n\n ']
# 71064 ['thumb|„A w', '05-12].\n\n ']
# 610 ['Anarchia (', 'zypisy \n\n*']
# 20098 ['To juz prz', 'i nadal są']
# 1983 ['ASN.1 (skr', 'puterowych']
# 21297 ['Algorytm –', 'anych\n \n\n ']
# 750 ['Przylądek ', ' Zachodnia']
# 3682 ['thumb|100p', 'zypisy \n\n ']
# 19245 ['Agatha Chr', 'rli w 1976']
# 3273 ['Allel – je', 'zaje genów']
# 10172 ['Anatole Fr', 'rli w 1924']
# 8147 ['Alkaloidy ', 'zypisy \n\n ']
# 21 ['REDIRECT A', 'tropologia']
# 19105 ['thumb|Rato', ' Świata\n\n ']
# 8226 ['Andrespol ', 'ie łódzkim']
# 8464 ['Andrzejewo', 'zowieckie)']
# 5263 ['Aminy – or', '\n \n\n\n\n\n\n\n ']
# 4639 ['Aceton, pr', 'szczalniki']
# 17883 ['thumb|Dzie', '-10].\n \n\n ']
# 107 [' energetyk', 'nych Gitar']
# 6209 ['Polonezköy', 'ji Stambuł']
# 985 ['thumb|Zrzu', 'operacyjne']
# 1925 ['thumb|300p', 'acyjne IBM']
# 7407 ['thumb|315p', 'a roślinna']
# 2101 ['Acetylocho', 'komimetyki']
# 10903 ['Adobe Phot', ' rastrowej']
# 3468 ['alt=|thumb', 'zypisy \n\n!']
# 11653 ['mały|230px', ':Komputery']
# 24051 ['thumb|Alba', 'ołudniowej']
# 25057 ['Austria (,', 'dnoczonych']
# 11605 ['Andora, Ks', 'Zachodniej']
# 663 ['Aromorfoza', 'a:Ewolucja']
# 8745 ['Azot (N, )', ':Alotropia']
# 3084 ['Amedeo Avo', 'rli w 1856']
# 1683 ['Uwierzytel', 'Metrologia']
# 4431 ['Autoryzacj', 'ytelnienie']
# 8984 ['thumb|Alfa', 'zypisy \n\n ']
# 739 ['Akronim AM', 'rzenośnych']
# 1260 ['Wieloproce', 'komputerów']
# 874 ['mały|Plaka', 'Poligrafia']
# 10197 ['Asembler (', 'nguage.\n\n ']
# 32 ['REDIRECT O', 'e użytkowe']
# 4569 ['thumb|Jodl', 'rli w 1946']
# 12238 ['Antonio de', 'a-Enríquez']
# 22622 ['Armia Radz', ' Radziecka']
# 2946 ['Argon (Ar,', 'szlachetne']
# 11524 ['mały|Czter', ' kulturowa']
# 1328 ['Achtung – ', 'kie z 1937']
# 13596 ['thumb|Tabl', 'talitaryzm']
# 220 [' Aleksande', ' – filozof']
# 2567 [' () – inst', 'non-profit']
# 1121 ['Abelard – ', 'germańskie']
# 1034 ['thumb|Lapo', ' społeczne']
# 8750 ['thumb|240p', '212 p.n.e.']
# 27974 ['Arystofane', 'eku p.n.e.']
# 4819 ['Amonity, a', 'rzne \n \n\n ']
# 3147 ['Alfabet he', 'ne \n \n \n\n ']
# 10269 ['Albert Cam', 'rli w 1960']
# 791 [' geografia', 'obacz też ']
# 166 [' Alaska – ', 'Spokojnego']
# 215 [' Arizona –', 'Hondurasie']
# 36345 ['Alabama (w', 'dnoczonych']
# 11893 ['Alaska () ', 'dnoczonych']
# 7200 ['thumb|250p', 'Kontynenty']
# 878 ['Aleksandr ', 'oria:Kupcy']
# 501 ['Alabama ()', 'cze Mobile']
# 914 ['thumb|250p', 'ny Ameryki']
# 15691 ['Arizona ()', 'dnoczonych']
# 18028 ['thumb|Kadr', 'ki filmowe']
# 6308 ['Arkansas (', 'dnoczonych']
# 32505 ['Ameryka Po', 'Kontynenty']
# 13623 ['thumb|Peni', 'olsce\n \n\n ']
# 15897 ['thumb|righ', 'lergologia']
# 43469 ['Alergia (p', 'mmunologia']
# 7808 ['Algorytm E', '\nEuklidesa']
# 420 ['thumb|Argy', 'l and Bute']
# 563 ['Adaptive T', 'ki dźwięku']
# 8965 ['Antoninus ', 'arli w 161']
# 615 ['thumb|250p', 'a:Germanie']
# 4542 ['mały|250x2', ' VII wieku']
# 9243 [' kontrower', '023 (CEST)']
# 473 ['Autostereo', 'Stereotypy']
# 14657 ['mały|240px', 'łaciński\n ']
# 58691 ['Albert Ein', 'rli w 1955']
# 20522 ['Alfabet gr', ' \n \n \n \n\n ']
# 2674 [' Alba – im', ' Przypisy ']
# 929 ['320px|thum', 'j Brytanii']
# 881 ['Awienus, w', 'ta śmierci']
# 1475 ['thumb|300p', 'dowa Ziemi']
# 98 [' Alfa Cent', 'rine Dream']
# 1627 ['thumb|righ', 'dnoczonych']
# 4310 ['thumb|250p', 'u Kolorado']
# 4117 ['245px|thum', 'w Islandii']
# 1965 ['mały|Model', 'omagnetyzm']
# 11077 ['thumb|Mężc', 'ia Japonii']
# 3030 ['thumb|250p', 'połeczne\n ']
# 1834 ['W USA dopr', '014 (CEST)']
# 8086 ['mały|Dymsz', 'rli w 1975']
# 15047 ['Anna Sierg', 'skich 1996']
# 2750 ['Aleksander', 'rli w 1891']
# 12705 ['mały|dom A', 'rli w 1861']
# 2941 ['Achajowie ', 'a mykeńska']
# 17346 ['mały|Portr', 'rli w 1966']
# 4163 ['Abu Simbel', 'ego Egiptu']
# 1074 ['thumb|200p', 'leksandria']
# 4944 ['thumb|350p', 'ni w Mekce']
# 21350 ['thumb|200p', 'ychodeliki']
# 98806 ['Alfred Jos', 'rli w 1980']
# 19983 ['Australia,', 'u Pacyfiku']
# 1751 ['Rijad (, A', 'stw w Azji']
# 61146 ['Argentyna ', 'ołudniowej']
# 3809 ['Andreas Ve', 'rli w 1564']
# 13 ['REDIRECT A', 'IRECT A/52']
# 601 ['Athene – k', 'je Linuksa']
# 12497 ['Adrenalina', 'sychologia']
# 3709 ['mały|Plan ', 'cts Agency']
# 3408 ['Akwarela (', ' malarskie']
# 3038 ['André Paul', 'rli w 1951']
# 74939 ['thumb|upri', ' światowej']
# 493 [' am, AM, a', 'a muzyczna']
# 6244 ['thumb|Niem', 'III Rzeszy']
# 1125 ['ASP (ang. ', ' skryptowe']
# 1940 ['Auto-Ordna', 'brojeniowe']
# 19 ['REDIRECT S', 'Skrótowiec']
# 30 ['PRZEKIERUJ', 'kenazyjscy']
# 353 ['Asymilacja', '. ksenolit']
# 438 ['Alfabet hu', '.\n\nHusycki']
# 4787 ['Asembler x', 'ektura x86']
# 959 ['Ada – imię', 'a semickie']
# 7638 ['thumb|Thom', 'lozoficzna']
# 16497 ['thumb|Alek', 'rli w 1999']
# 50255 ['Ateizm (z ', '05-12].\n\n ']
# 171153 [' Ateista \n', '7.30.21.87']
# 84 [' Koniunkcj', 'n, Seszele']
# 1114 ['Alan Cox (', 'w Solihull']
# 17280 ['mały|200x2', 'rli w 2008']
# 1869 ['thumb|Pomi', 'a fizyczna']
# 5393 ['Ares (gr. ', 'stwa wojny']
# 5392 ['mały|prawo', 'a przyrody']
# 31735 ['Atena (gr.', 'e z Odysei']
# 1592 ['thumb|310p', 'nie tekstu']
# 1118 ['Moja znajo', '011 (CEST)']
# 10776 ['Czy amfeta', '021 (CEST)']
# 53015 ['Aborcja ( ', 'lona)\n \n\n ']
# 3345 ['thumb|Poró', 'rzne \n \n\n ']
# 1506 ['Arthur Joh', 'lu Copleya']
# 5802 ['Antymateri', '06-26].\n\n ']
# 4009 ['Akromegali', 'nologiczne']
# 3709 ['Amidy – or', 'zypisy \n\n ']
# 4424 ['thumb|Kolo', 'ne \n \n \n\n ']
# 1746 ['mały|Archi', 'ą fizyczną']
# 1588 ['Antologia ', 'ria:Muzyka']
# 5163 ['Przekierow', '008 (CEST)']
# 56 [' Andorra –', ' w Europie']
# 1090 ['thumb|Anon', 'Prywatność']
# 1219 ['Asowie\n\n l', 'Dynastie\n ']
# 705 [' Armia Kra', 'rika Korps']
# 5236 ['thumb|300p', 'dowa Ziemi']
# 811 ['thumb|upri', 'v:Anakoret']
# 2361 ['thumb|\nAut', 'alestyńska']
# 452 ['Agrypina (', ' łacińskie']
# 3163 ['Agrypina S', 'li z głodu']
# 4414 ['Agrypina M', 'marli w 59']
# 27 ['REDIRECT D', ' Antoninów']
# 6416 ['Aleksander', 'onarchowie']
# 957 ['Aurelian –', ' łacińskie']
# 503 ['Lucius Ael', 'arli w 138']
# 25 ['redirect E', 'n (cesarz)']
# 502 [' \n\nAmandus', ' urodzenia']
# 1946 ['Arkadiusz,', 'arli w 408']
# 12744 ['Apple Inc.', ' na NASDAQ']
# 351 [' Aelianus ', 'arli w 286']
# 1842 ['thumb|240p', ' III wieku']
# 1384 ['thumb|Ręka', 'omunikacji']
# 15 ['REDIRECT A', 'ECT Awitus']
# 15 ['REDIRECT A', 'ECT Awitus']
# 5265 ['Prokopiusz', 'arli w 472']
# 18 ['REDIRECT A', ' Antemiusz']
# 5284 ['Eparchiusz', 'arli w 457']
# 15 ['REDIRECT A', 'ECT Awitus']
# 13333 ['W dermatol', 'mmunologia']
# 734 ['thumb|Atop', 'mmunologia']
# 5042 ['Alicja Gra', 'eni w 1985']
# 44 ['Aksapo sta', 'm --Matusz']
# 10679 ['Alexander ', 'h na Ziemi']
# 23 ['REDIRECT A', 'st (tytuł)']
# 345 [' abakus (a', 'ik do gier']
# 527 ['Antygrawit', 'ntastyczna']
# 58733 [' (wym. //;', ' samobójcy']
# 25251 ['Azja (gr. ', 'Kontynenty']
# 33060 ['Uniwersyte', 'w Polsce\n ']
# 13115 ['mały|Słowi', 'asłowianie']
# 29 ['redirect A', 'orporacja)']
# 1123 ['Alfabet ar', 'i semickie']
# 12974 ['Uczelnie m', ' dziedziny']
# 740 ['Antonia – ', 'ię żeńskie']
# 693 ['Auto – gat', 'oria:Teatr']
# 1862 ['thumb|Arma', ' \n \n \n \n\n ']
# 22447 ['thumb|274p', 'zne w 1969']
# 1127 ['Apollo 11 ', 'j w Afryce']
# 7438 ['Alcatraz I', ' Francisco']
# 2604 ['thumb|150p', 'formatorer']
# 6580 ['mały|Medal', 'yk arabski']
# 563 ['Astma (łac', ' Przypisy ']
# 350 ['atto (a; z', 'IPM)\n\natto']
# 25 ['REDIRECT O', 'Atlantycki']
# 1056 ['Angstrem (', 'od nazwisk']
# 2363 ['Amper – je', 'od nazwisk']
# 2114 ['right|65px', 'noliterowy']
# 1430 ['right|200p', 'zypisy \n\n ']
# 4892 ['mały|Azja ', 'Trójka)\n\n ']
# 10523 ['Azja Zacho', 'giony Azji']
# 1684 ['thumb|315p', 'giony Azji']
# 2200 ['thumb|350p', ' Zachodnia']
# 15518 ['thumb|240p', 'asta Łodzi']
# 767 ['Luksemburg', ' Al Bundy)']
# 452 ['Geografia:', '\n\n Ahr\n AR']
# 1124 ['Belgia:\n A', 'z też \n AS']
# 9233 ['Abu Nidal ', 'rli w 2002']
# 24 ['REDIRECT C', 'osomy płci']
# 719 ['Autosomy –', 'Chromosomy']
# 25 ['REDIRECT A', 'Senefelder']
# 6067 ['Afrodyzjak', 'choaktywne']
# 3465 ['Anastazjus', 'a piorunem']
# 57194 ['Andrzej Wi', ' Wikipedii']
# 5065 ['Anthony Mi', 'a Oliviera']
# 35497 ['Adam Berna', 'na cholerę']
# 7138 ['Adam Stani', 'rli w 2019']
# 487 [' album – w', ' The Album']
# 622 ['Alfabet ha', 'k hawajski']
# 3893 ['Ahenobarbu', 'Ahenobarbo']
# 21301 ['Antropolog', 'icznego\n\n ']
# 25 ['REDIRECT A', 'nder Sewer']
# 3115 ['Adobe Illu', 'wektorowej']
# 3707 ['Aureus, nu', 'ote monety']
# 6284 ['As (skr. o', 'y rzymskie']
# 1102 ['thumb|righ', ':Karakalla']
# 14034 ['thumb|Hans', 'ograficzne']
# 4739 ['thumb|250p', 'umizmatyka']
# 25 ['REDIRECT E', 'n (cesarz)']
# 1284 [' Ortografi', ' Aue\n Auen']
# 15 ['REDIRECT S', 'ECT Srebro']
# 14 ['REDIRECT A', 'RECT Aktyn']
# 306 [' at – jedn', ' \n AT\n Ath']
# 11800 ['thumb|Rozw', 'chemenidów']
# 6509 ['thumb|280p', ' \n \n \n \n\n ']
# 864 ['Nazywam si', 'G #2036873']
# 5 ['Ajank', 'Ajank']
# 19848 ['thumb|upri', 'cji Ankara']
# 2766 ['mały|„Ario', 'owedyjskie']
# 8948 ['Asyria (ak', 'e biblijne']
# 1348 ['Afrochrześ', 'a w Afryce']
# 2299 ['Arabizm – ', 'zyk polski']
# 2543 ['mały|200px', 'ta-Laktony']
# 2671 ['Abbott i C', 'scy komicy']
# 3192 ['Absolwent ', 'b musicalu']
# 1887 ['thumb|Akwa', 'niki druku']
# 1382 ['Aedh, Aed,', 'arli w 878']
# 2464 ['thumb|250p', 'rli w 1858']
# 5635 ['Heinrich A', 'rli w 1888']
# 45 ['REDIRECT Z', 'odporności']
# 3914 ['Antygen (ź', 'zypisy \n\n ']
# 1739 [' – japońsk', ' japońskie']
# 22726 ['mały|450px', 'ria:Shintō']
# 18705 ['thumb|Etap', 'nologiczny']
# 18 ['REDIRECT W', ' Witeliusz']
# 11117 ['thumb|240p', 'wersytetów']
# 257 [' aha – ukr', 'roksykwasy']
# 10605 ['mały|240px', 'enistyczne']
# 265 ['Amenhotep ', ' jest rad"']
# 3539 ['Alexander ', 'rli w 1955']
# 162 ['ASVD (ang.', 'ria:Modemy']
# 1174 ['Adenina, 6', 'ukleotydów']
# 2221 ['thumb|Anto', ' w Delfcie']
# 508 ['mały|Półno', 'konomiczna']
# 7872 [' Wyspy Arc', 'res.com\n\n ']
# 5430 ['Alfred Rus', 'oyal Medal']
# 1777 ['thumb|Lite', 'cka\n\nGocki']
# 4506 ['Albert Sch', 'rli w 1965']
# 4610 ['Aldous Leo', 'on College']
# 9458 ['thumb|Pała', 'rli w 1876']
# 2815 ['Ambrose Gw', 'eni w 1842']
# 25 ['REDIRECT A', ' de Musset']
# 2396 ['thumb|Grób', 'rli w 1857']
# 14276 ['thumb|Grób', 'rli w 1972']
# 11511 ['"W 1934 ro', 'rli w 1976']
# 13627 ['Arthur Sch', 'rli w 1860']
# 18858 ['Alan Mathi', ' samobójcy']
# 170 [' Andriej A', 'i hokeista']
# 2216 ['August Fer', 'matycznych']
# 884 ['Armator – ', 'ia:Żegluga']
# 1332 ['thumb|Amer', 'Kontynenty']
# 2221 ['Ameryka Ce', 'a Północna']
# 809 ['250px|thum', 'ny Ameryki']
# 2946 ['250px|thum', '(minerały)']
# 1369 ['Argentyt (', 'ria:Srebro']
# 2875 ['thumb|250p', 'j Gwinei\n ']
# 5623 ['thumb|Pała', 'Petersburg']
# 19002 ['thumb|Anna', 'rli w 2010']
# 7337 ['thumb|Afis', 'ku włoskim']
# 23 ['PATRZAida_', 'era)#Osoby']
# 21073 ['Amnesty In', 'y Erazmusa']
# 2956 ['Alban Mari', ' zwierzęta']
# 1398 ['Aleksandr ', 'rli w 1887']
# 760 ['Action Int', 'ozarządowe']
# 11514 ['thumb|250p', 'le religii']
# 13926 ['Alimenty (', ' społeczne']
# 1752 ['thumb|Przy', 'oria:Druki']
# 1206 ['Astrometri', 'zypisy \n\n ']
# 25 ['REDIRECT A', 's Schlüter']
# 25 ['REDIRECT A', 's Schlüter']
# 851 ['thumb|240p', 'a sakralna']
# 1583 ['Avarua – s', 'ria:Avarua']
# 5674 ['Antyle Hol', 'zypisy \n\n ']
# 2288 ['300x300px|', 'ny liczące']
# 11637 ['thumb|Jace', ' Wikipedii']
# 2655 ['thumb|280p', 'komputerów']
# 964 ['thumb|300x', 'komputerów']
# 3124 ['Biedrzenie', ' Linneusza']
# 2433 ['Arkusz wyd', 'egoria:DTP']
# 2274 ['Automatycz', 'rzne \n \n\n ']
# 4096 ['Andrea del', ' Florencji']
# 3757 ['thumb|240p', ' Grenadzie']
# 2204 ['Arytmetyka', 'Arytmetyka']
# 1125 ['Antonim (z', 'oznawstwie']
# 684 ['thumb|Abra', 'er Abraham']
# 17 [' #PATRZara', 'arabistyka']
# 3654 ['thumb|Ruin', 'wa miłości']
# 7587 ['Apollo (gr', 'stwa sztuk']
# 254 [' akcent – ', ' \n Akcenty']
# 725 ['Audiatur e', ' prawnicze']
# 1117 ['ALICE (Art', 'gramowanie']
# 4114 ['Minimax (c', 'szukiwania']
# 7329 ['thumb|400p', '\nAlfa-beta']
# 4563 ['Alfred Ber', 'rli w 1896']
# 2841 ['Asertywnoś', 'zypisy \n\n ']
# 1647 ['Amfifilowo', ' chemiczne']
# 33023 ['Arystotele', 'eku p.n.e.']
# 4487 ['Atropina (', 'Oneirogeny']
# 16928 ['Ateny  (no', 'nie Attyka']
# 17874 ['Ajschylos,', 'eku p.n.e.']
# 1756 ['Advocaat|t', 'olenderska']
# 6867 ['Anna Maria', ' Warszawie']
# 19 ['REDIRECT A', 'Anna Mucha']
# 1941 ['Algorytm r', 'kim\n\nrsync']
# 1761 ['thumb|300p', 'cyjnych\n\n ']
# 2925 ['thumb|300p', 'rzne \n \n\n ']
# 563 ['thumb|Brud', ' piśmienne']
# 2140 [' Bogdan Mi', 'ikipedyści']
# 32 ['REDIRECT B', 'Krzywousty']
# 4254 ['Biologia m', '05-12].\n\n ']
# 7373 ['Behawioryz', 'zne\n \n \n\n ']
# 2622 ['BeOS – sys', 'operacyjne']
# 1819 ['kolordługo', 'ria koloru']
# 1685 ['Barwy achr', 'ria koloru']
# 2103 ['Barwy chro', 'ria koloru']
# 506 ['Barwy złoż', 'ria koloru']
# 551 ['Bryt – pas', 'nty ubioru']
# 2723 ['Bit (z ang', 'informacji']
# 186 [' bajt – je', ' od „Bajt”']
# 749 ['thumb|246p', 'zy jachcie']
# 225 [' buchtowan', 'ożywienia.']
# 9982 ['Baza danyc', 'pnia)\n \n\n ']
# 1659 ['Fajnie, że', '[polimerek']
# 1726 ['thumb|200p', 'ria koloru']
# 1017 ['Barwy dope', 'lorymetria']
# 5051 ['thumb|Ferr', 'ria koloru']
# 4143 ['Benzoesan ', 'nzoesowego']
# 252022 ['mały|Bydgo', ' XIV wieku']
# 2976 [' białka – ', ' Przypisy ']
# 24 ['REDIRECT B', 'd Makowski']
# 14 ['REDIRECT B', 'RECT Björk']
# 35830 ['thumb|upri', 'ołudniowej']
# 18220 ['Belgia, Kr', ':Królestwa']
# 18792 ['Bośnia i H', 'ołudniowej']
# 22551 ['Bułgaria, ', 'ołudniowej']
# 6358 ['Beryl (Be,', 'hemiczne\n ']
# 5122 ['Bor (B, ) ', 'egoria:Bor']
# 49408 ['thumb|Koło', 'ddyjski\n\n ']
# 198 ['Bubel (And', 'w wypadku.']
# 10313 ['thumb|200p', '9-18]\n \n\n ']
# 2165 [' Podstawa ', 'ynorobca".']
# 3416 ['thumb|387p', 'iologiczne']
# 20739 ['thumb|280p', ' japońskie']
# 128605 ['mały|uprig', 'rli w 1138']
# 6889 ['bash – pow', 'pisane w C']
# 1583 ['bzip2 – al', ' kompresji']
# 8074 ['thumb|Biał', 'Fotometria']
# 10217 ['thumb|240p', 'rli w 1976']
# 430 ['Bariera ku', 'ia kultury']
# 2823 ['thumb|Blit', 'y wojskowe']
# 5447 ['Bernardo B', ' w Wenecji']
# 2758 ['Brom (Br, ', ' chemiczne']
# 16074 ['thumb|240p', 'Gór Polski']
# 2711 ['Bantustan ', 'ustany \n\n*']
# 547 ['Basic Engl', 'gielskiego']
# 9923 ['Beskidy (c', ' Wikipedii']
# 11033 ['thumb|240p', ' Wikipedii']
# 1953 ['Beskidy Za', 'y Słowacji']
# 4789 ['Bolesław C', 'iteraturze']
# 1086 [' Morze Bał', 'pożywczego']
# 3865 ['Beskid Mak', 'wskiego\n\n ']
# 3097 ['mały|Lokal', ' lechickie']
# 1060 ['Biskupin (', 'żnińskiego']
# 13335 [' (ur. 986 ', 'e Artykuły']
# 7547 ['Boudika, B', 'marli w 61']
# 1998 ['thumb|200p', 'j Brytanii']
# 11924 ['thumb|upri', 'dnoczonych']
# 9107 ['Burowie (t', 'arodowości']
# 1860 ['Niedźwiedź', 'na Pallasa']
# 632 ['Biogeograf', '\n\n\n\n\n\n\n\n\n ']
# 12453 ['Brigitte A', 'eni w 1934']
# 49702 ['Mjanma\n\nMi', 'dnoczonych']
# 1626 ['Biegun geo', ':Nawigacja']
# 12910 ['thumb|Bron', ' Wikipedii']
# 4018 ['BSD (ang. ', 'operacyjne']
# 2837 ['thumb|Trik', 'ria:Rowery']
# 48732 ['thumb|Bisk', 'arytologia']
# 35920 ['Berlin – s', 'we Niemiec']
# 9961 ['240px|thum', 'Argentynie']
# 3294 ['mały|Sprzę', '1995]\n \n\n ']
# 4528 ['BITNET – z', 'nformatyki']
# 589 ['thumb|Aleg', 'olucyjnego']
# 12621 ['mały|Bertr', 'rli w 1970']
# 6833 ['Blender – ', 'pisane w C']
# 4641 ['Beretta M9', 'ne Beretta']
# 8346 ['thumb|Wyst', '\n  \n \n \n\n ']
# 4689 ['Biblioteka', 'zypisy \n\n ']
# 5004 ['Boris Leon', 'eccy Żydzi']
# 26284 ['mały|Wnętr', 'skich\n \n\n ']
# 453 ['Binutils –', 'egoria:GNU']
# 876 ['thumb|Leon', 'ria koloru']
# 2098 ['Benoît B. ', 'oris causa']
# 22169 ['William „B', 'Microsoftu']
# 5908 ['thumb|200p', 'edeńskiego']
# 4212 ['thumb|Symb', 'rodą Nobla']
# 2645 ['Bozony ( o', 'zypisy \n\n ']
# 513 ['200px|thum', 'mputerowa)']
# 736 ['Bozon Z0 (', 's#Z_bosons']
# 4680 ['thumb|Bale', ' sceniczne']
# 25 ['REDIRECT M', 'gia grecka']
# 2909 ['Budżet (z ', ' publiczne']
# 750 ['thumb|Pros', 'two islamu']
# 7283 ['Brainfuck\n', 'gramowania']
# 1969 ['thumb|240p', 'a mądrości']
# 1453 ['Bogowie w ', ' Wikipedii']
# 600 ['Bobina – b', 'Poligrafia']
# 587 ['thumb|Sche', 'oria:Druki']
# 3932 ['thumb|Big ', ':Postpress']
# 12 ['REDIRECT Z', 'DIRECT Zen']
# 9264 ['250px|mały', 'ia:Judaizm']
# 2275 ['thumb|240p', 'agiografia']
# 459 ['Błogosławi', 'agiografia']
# 1966 ['Brytanik (', 'marli w 55']
# 15 ['REDIRECT B', 'ECT Balbin']
# 580 ['Balbin (ła', ' łacińskie']
# 629 ['Osoby\n Mar', 'omputerowy']
# 17 ['REDIRECT B', 'T Brytanik']
# 997 ['right|thum', 'eologiczne']
# 501 ['Bonosus – ', 'arli w 280']
# 10250 ['Bitwa pod ', 'XVII wieku']
# 5001 ['mały|316px', 'łowiańskie']
# 6287 ['thumb|Radz', ' 1995, \n\n ']
# 58 ['REDIRECT B', ' skrótowce']
# 44011 ['160px|thum', 'e Artykuły']
# 2625 ['thumb|240p', ' podlaskim']
# 621 ['Biliard – ', 'azwy liczb']
# 568 ['Bilion (sk', 'azwy liczb']
# 33 ['REDIRECT U', 'k miar CGS']
# 2002 ['right|100p', 'oliterowy.']
# 3889 ['thumb|300p', 'giony Azji']
# 11 ['REDIRECT g', 'EDIRECT go']
# 3519 ['thumb|240p', ' gorlickim']
# 4994 ['thumb|Buki', ' Linneusza']
# 400 [' Be – symb', 'z też \n BE']
# 13 ['REDIRECT B', 'IRECT Brom']
# 2441 ['Znaczenie ', '08\u200e (CEST)']
# 774 ['thumb|Frog', 'goria:BDSM']
# 58330 ['Bytom (, ,', 'gdeburskim']
# 112837 ['Bielsko-Bi', 'w XX wieku']
# 10877 ['thumb|Zapi', ' państwowe']
# 812 ['Bazyliskus', ' w V wieku']
# 142 ['Beacik - w', '. --Matusz']
# 4548 ['thumb|240p', 'głoskowcem']
# 24138 ['mały|Zwój ', 'iterackich']
# 7918 ['Historyczn', 'gguna:Boud']
# 31 ['PATRZ Bitw', 'awą (1656)']
# 5124 ['thumb|350p', 'ane monety']
# 2570 ['thumb|180p', 'niowieczne']
# 347 [' płaca bru', 'eż \n netto']
# 524 [' ban – jed', 'eralny ONZ']
# 625 [' Mitologia', 'sh Airways']
# 15 ['REDIRECT b', 'ECT berkel']
# 24786 ['thumb|240p', 'mazowieccy']
# 24922 ['thumb|290p', 'z XX wieku']
# 152 [' Cesarstwo', 'antyńskiej']
# 27 ['REDIRECT B', 'm (miasto)']
# 17974 ['Björk Guðm', 'ki filmowe']
# 7264 ['thumb|Żołn', ' wynalazki']
# 1635 ['Bechowiec ', ' wynalazki']
# 11643 ['Babilonia ', 'graficznej']
# 3525 ['thumb|Typo', ':Aborygeni']
# 9797 ['Błaszki ()', '-sieradzka']
# 7394 ['thumb|Braz', '(Brazylia)']
# 2310 ['mały|Willi', 'niowieczna']
# 2225 ['240px|thum', ' japońskie']
# 6914 ['thumb|Dawn', 'oria:Miedź']
# 18192 ['thumb|Słow', 'ia:Samuraj']
# 3197 ['thumb|Prow', 'Boudiki\n\n ']
# 1758 ['Białka adh', 'ka błonowe']
# 73 [' Biwa (ins', ' (jezioro)']
# 1316 ['Briologia ', 'zypisy \n\n ']
# 6197 ['Bardzo waz', ' powiązać.']
# 3985 ['Borland (w', 'ą w Austin']
# 30569 ['Święta Boż', 'ścijańskie']
# 3156 ['thumb|Dzie', 'a fizyczna']
# 14320 ['thumb|240p', 'rli w 1677']
# 14945 ['thumb|Benj', 'ytetu Yale']
# 9920 ['thumb|upri', 'cy pisarze']
# 37074 ['thumb|Jedn', 'atolicyzmu']
# 843 ['Blenda ura', 'erwiastek)']
# 6992 ['mały|Szach', 'o wojskowe']
# 5243 ['Ballada o ', 'oria Gdyni']
# 117 [' Bezpartyj', '1993–1997)']
# 1530 ['Bel canto,', 'romantyzmu']
# 16041 ['thumb|200p', 'rli w 1945']
# 1457 ['Bekerel, B', 'ochodne SI']
# 16 ['REDIRECT b', 'CT bekerel']
# 886 ['thumb|250p', 'rli w 1592']
# 13932 ['thumb|Gien', 'sorgskiego']
# 16388 ['thumb|Bron', 'a Europaea']
# 23462 ['thumb|List', ' Czehryniu']
# 1199 ['Borowski (', 'e nazwiska']
# 866 ['Białoruski', 'studenckie']
# 7388 ['thumb|Lito', '\n\noc:Conte']
# 797 ['Beczuana (', 'j Brytanii']
# 2581 ['Brytyjskie', ' Północnej']
# 2055 ['thumb|Mari', ':Romantyzm']
# 1978 ['thumb|300p', ':Zamieszki']
# 12299 ['mały|Czerw', 'zypisy \n\n ']
# 2977 ['Mam bardzo', '007 (CEST)']
# 270 [' Brutalna ', 'algorytmów']
# 7805 ['300px|thum', 'iologiczne']
# 627 ['thumb|200p', ' Florencji']
# 2295 ['thumb|Pers', 'rli w 1571']
# 3758 ['thumb|250p', ' Linneusza']
# 23 ['REDIRECT p', 'owity bóbr']
# 772 ['thumb|210p', 'ożarnictwo']
# 8162 ['Bliźnięta ', ' Guide \n\n ']
# 15258 ['Bona Sforz', ' Wikipedii']
# 507 ['thumb|160p', 'strażackie']
# 4819 ['Czechizm, ', 'y językowe']
# Chunk 2 of 8388608 bytes <class 'str'>
# 662 ['Bohemia – ', 'j Zelandii']
# 1208 ['Bebop (rów', 'le jazzowe']
# 65062 ['thumb|Wład', ' Wikipedii']
# 22863 ['Bolesław V', 'niowiecze)']
# 14170 ['Bitwa pod ', ' Gorlicami']
# 3996 ['thumb|350p', ' \n \n \n \n\n ']
# 19656 ['Bitwa pod ', 'pod Lenino']
# 940 ['Bison – ge', 'egoria:GNU']
# 14558 ['Bronisław ', 'nografowie']
# 295 ['Babaszka, ', ':Zecerstwo']
# 5287 ['thumb|Synt', 'oaktywne\n ']
# 2048 ['thumb|Abdo', ' lekarskie']
# 27 ['REDIRECT W', 'an foremny']
# 4774 ['Baran (łac', ' Guide \n\n ']
# 11633 ['Bruksela (', 'm Brukseli']
# 1078 ['Biopolimer', ', s. 53\n\n ']
# 1655 ['Biotyna ( ', 'icykliczne']
# 17 ['REDIRECT B', 'T Bakterie']
# 8394 ['PYTANIE:\nP', '2017 (CET)']
# 4603 ['Burrhus Fr', 'of Science']
# 4789 ['Bitwa na P', ' Psim Polu']
# 2229 ['Bromowodór', 'ązki bromu']
# 4653 ['thumb|200p', 'szczalniki']
# 3366 ['\\n\nZastana', '012 (CEST)']
# 11998 ['thumb|280p', 'y:Хирургия']
# 29395 ['Chemia org', 'n. \n \n \n\n ']
# 2356 ['Chemia fiz', 'zypisy \n\n ']
# 8244 ['thumb|200p', 'Typografia']
# 2179 ['mały|Przyk', '12-03].\n\n ']
# 5691 ['\\n\nZastana', '2005 (CET)']
# 13652 ['mały|Płyta', 'kompaktowe']
# 695 ['CPAN () – ', 'goria:Perl']
# 18 ['REDIRECT W', ' Wikipedia']
# 4854 ['CP/M (ang.', 'operacyjne']
# 250 ['Tu kierują', 'a. RomanK.']
# 18 ['REDIRECT W', ' Wikipedia']
# 1342 ['right\nC – ', 'oliterowy.']
# 10346 ['C++ – języ', 'etwork \n\n ']
# 674 ['Chemia ana', 'ączone.\n\n ']
# 853 ['Chemiczna ', 'nalityczna']
# 4899 ['thumb|120p', 'zypisy \n\n ']
# 3164 ['SV Cutty S', ' XIX wieku']
# 16798 ['thumb|250p', 'rafik).\n\n ']
# 1020 ['Cytochromy', ' \n\n\n\n\n\n\n\n ']
# 1475 ['thumb|Mode', 'zypisy \n\n ']
# 1815 ['mały|Szkla', 'yka cieczy']
# 2498 ['Cyfra – um', 'y liczbowe']
# 5768 ['thumb|Szkl', 'y z owoców']
# 4709 ['thumb|200p', 't Calvados']
# 2969 ['Czeski błą', 'egoria:DTP']
# 2161 ['Miejsce ak', 'nzymologia']
# 2521 ['Celuloza (', 'isacharydy']
# 19088 ['250px|righ', 'yfrowej\n\n ']
# 3416 ['Chinina ()', 'ji Zdrowia']
# 4716 [' \nCywiliza', ' kulturowa']
# 60250 ['mały|Częst', 'ie śląskim']
# 83 ['Podoba mi ', 'a hasłami.']
# 37 ['PATRZ Funk', 'eoznaczona']
# 765 ['Całka ozna', '\noznaczona']
# 48 ['PATRZcałka', 'a-Leibniza']
# 15739 ['thumb|Całk', 'rd Riemann']
# 14 ['REDIRECT O', 'RECT OCaml']
# 9637 ['COBOL (akr', 'gramowania']
# 24044 ['Chile (, )', 'u Pacyfiku']
# 29755 ['Chorwacja,', 'ołudniowej']
# 15 ['REDIRECT C', 'ECT Czechy']
# 695 ['Cefalizacj', 'a:Ewolucja']
# 6073 ['Ciepło wła', 'específica']
# 6599 ['Ciepło w f', 'dynamiczne']
# 45880 ['mały|240x2', 'rli w 2004']
# 32572 ['Chrześcija', ' \n \n \n \n\n ']
# 50379 ['Chojnów ()', 'XIII wieku']
# 457 ['Chemiczna ', 'nalityczna']
# 2744 ['Ciśnienie ', 'dynamiczne']
# 50055 ['Chemiczna ', 'organiczna']
# 1391 ['Chlorki – ', 'logenki\n\n ']
# 3498 ['Computer t', ' offsetowy']
# 2869 ['Computer t', ' offsetowy']
# 824 ['Chemia nie', 'icznymi\n\n ']
# 512 [' Definicja', 'o to jest ']
# 1367 ['Chemia teo', 'a fizyczna']
# 1764 ['Cimabue, w', 'rli w 1302']
# 40 ['PATRZ Clau', 'auffenberg']
# 7051 ['Chlor, Cl ', 'Utleniacze']
# 25 ['REDIRECT s', 'ytny Egipt']
# 1080 [' Centralna', 'rowanych).']
# 33 ['REDIRECT K', 'sze stylów']
# 1420 ['Uważam, że', 'cji. --Taw']
# 1694 [' – system ', 'rumieniowe']
# 148964 ['Marek Tull', ' 43 p.n.e.']
# 37516 ['mały|240x2', 'e Artykuły']
# 6422 ['Chrom (Cr,', 'hemiczne\n ']
# 38214 ['Michelange', 'e Artykuły']
# 5780 ['Cynk (Zn, ', ' chemiczne']
# 20181 ['Certyfikat', ' \n \n \n\n\n\n ']
# 7812 ['Cochise (c', 'merykański']
# 17268 ['Chester Wi', ' światowej']
# 5115 ['Szalony Ko', 'rli w 1877']
# 6153 ['CD-Audio, ', 'i optyczne']
# 17 ['REDIRECT C', 'T CD-Audio']
# 1190 ['thumb|250p', 'rożytności']
# 36004 ['Cypr, Repu', 'twa w Azji']
# 4444 ['Cypr (ang.', 'aństwowymi']
# 12116 ['thumb|Rząd', 'cholc\n \n\n ']
# 14832 ['Clement Ri', 'rli w 1967']
# 209 [' cyrkiel –', 'y czy hali']
# 1767 ['thumb|Polu', ' \n \n \n \n\n!']
# 8877 ['thumb|righ', 'dnoczonych']
# 7568 ['thumb|Herb', 'XIII wieku']
# 811 ['Charles Fr', 'ton (Ohio)']
# 19 ['PATRZTrial', 'l rowerowy']
# 7629 ['Czas – wie', '05-13].\n\n ']
# 23 ['REDIRECT S', 'fa czasowa']
# 1794 ['thumb|250p', 'goria:Czas']
# 2861 ['thumb|Stre', 'zypisy \n\n ']
# 6178 ['Czas środk', 'fy czasowe']
# 1287 [' Nazwa \n\nt', 'zypisy \n\n ']
# 6978 ['thumb|Cygw', 'pisane w C']
# 2222 ['Piłka rowe', ':Kolarstwo']
# 8586 ['mały|Roszc', 'zypisy \n\n ']
# 33 ['REDIRECT C', 'ika Ludowa']
# 23966 ['mały|Pekin', 'u Pacyfiku']
# 55224 ['Chrzest – ', ' w religii']
# 5072 ['mały|Gordo', 'w Londynie']
# 7397 ['Canberra (', ' i Oceanii']
# 26815 [' właśc. Jo', 'y na Medal']
# 6654 ['mały|Schem', 'goria:HTTP']
# 2843 ['thumb|300p', 'fia \n\n \n\n ']
# 1632 ['CISC (ang.', 'procesorów']
# 130 [' Chief exe', 'watelskiej']
# 23 ['REDIRECT K', 'l Linneusz']
# 23 ['redirect K', 'l Linneusz']
# 8740 ['Cząstka el', 'arnych.\n\n ']
# 2238 ['mały|Karta', 'wa książki']
# 28994 ['mały|Obraz', 'orems\n \n\n ']
# 1997 ['thumb|Ilum', 'ibliologia']
# 195 ['Czystopis ', 'egoria:DTP']
# 16668 ['Ciechanowi', 'w XV wieku']
# 205 ['Czystodruk', 'egoria:DTP']
# 1151 ['Czwartek (', 'ń tygodnia']
# 691 ['CLIPS (C L', 'gramowania']
# 158 [' Marcus Au', 'f przyrody']
# 1715 ['Claude Sim', 'narodowych']
# 23214 ['thumb|upri', 'cińskim\n\n ']
# 1132 ['thumb|Św. ', 'starożytne']
# 9640 ['thumb|320p', 'omputerowy']
# 52 [' Kaligula ', 'zaj motyla']
# 27 ['REDIRECT K', 'z (cesarz)']
# 18 ['REDIRECT K', ' Kommodus ']
# 23 ['REDIRECTCe', 'ze rzymscy']
# 2013 ['Jestem cie', '2004 (CET)']
# 13871 ['thumb|Okta', 'sarze\nRzym']
# 18 ['REDIRECT K', ' Karakalla']
# 108 [' Konstans ', 'ót const.)']
# 3246 ['Cursus hon', 'żytny Rzym']
# 2971 ['Karauzjusz', 'arli w 293']
# 835 ['Chycz – śr', 'y w Polsce']
# 8620 ['mały|300px', 'wnętrznych']
# 14291 ['Ciało skoń', 'informacji']
# 707 ['Cioty (zło', 'ria kobiet']
# 1878 ['Starożytni', '015 (CEST)']
# 1115 [' płyta kom', 'eské dráhy']
# 25 ['REDIRECT K', 'sz Albinus']
# 2740 ['Cal (ang. ', 'i długości']
# 1702 ['Don Camilo', 'lisyjczycy']
# 16341 ['thumb|300p', 'ncerna \n\n ']
# 156 ['Witam. Spr', 'i ?--Kpjas']
# 795 ['thumb|Ciąg', 'ia:Pojazdy']
# 710 ['thumb|Gąsi', ' specjalne']
# 9594 ['thumb|Ciąg', 'yleryjskie']
# 25 ['REDIRECT K', 'ncjusz III']
# 23 ['REDIRECT K', 'tantyn III']
# 306 ['Centy (c) ', ' \n \n\ncenty']
# 17321 ['Claus Phil', 'rli w 1944']
# 14 ['PATRZCenty', 'ZCentylion']
# 1716 ['Skad ta na', '2003 (CET)']
# 33 ['REDIRECT U', 'k miar CGS']
# 336 [' Gajusz Ju', 'omputerowa']
# 814 ['Centymetr ', 'nostki CGS']
# 460 [' CM – skró', 'ip Manager']
# 45343 ['C – impera', 'online.\n\n ']
# 7544 ['Choroby za', 'źnych\n\n \n!']
# 9308 [' – zestaw ', 'egoria:DTP']
# 8040 ['mały|alt=F', 'ia:Poetyka']
# 10995 ['Choroba Pa', ' ruchowych']
# 449 [' Ca – symb', 'cego około']
# 377 [' Cl, chlor', 'gramowania']
# 450 [' Chemia\n C', 'al filmowy']
# 9 ['TAM chrom', 'TAM chrom']
# 11 ['REDIRECT C', 'EDIRECT CU']
# 72650 ['mały|Plane', ' XIX wieku']
# 22 ['PATRZ Kary', 's (cesarz)']
# 27 ['REDIRECT K', 'z_II_Gocki']
# 1317 ['thumb|Sreb', 'marli w 68']
# 38 ['PATRZ Kons', 'zantyński)']
# 28 ['REDIRECT K', 'n I Wielki']
# 22 ['REDIRECT K', 'stantyn II']
# 31 ['REDIRECT K', ' I Chlorus']
# 24 ['REDIRECT K', 'ancjusz II']
# 28 ['REDIRECT K', 'usz Gallus']
# 570 ['Cezonia, w', 'y zabójstw']
# 21518 ['thumb|Chor', 'eścijańska']
# 6337 ['Gaius Cass', ' 42 p.n.e.']
# 321 [' Celsus (C', 'rs Celsius']
# 22 ['REDIRECT M', 'nt Everest']
# 11 ['REDIRECT k', 'EDIRECT k2']
# 43682 ['Bitwa Wars', ' Wikipedii']
# 477 [' Międzynar', 'lony Krzyż']
# 90 ['REDIRECTMi', 'Półksiężyc']
# 9819 [' Monastyry', '2023 (CET)']
# 28 ['REDIRECT T', 'ator Tesli']
# 275 [' cruzado –', ' 1989–1990']
# 839 ['thumb|10 c', 'ote monety']
# 869 ['thumb|40 d', 'ote monety']
# 2267 ['mały|Awers', 'ia:Wenecja']
# 27 ['REDIRECT K', 'z II Gocki']
# 23 ['redirectCy', ' II Wielki']
# 39366 ['thumb|Ilus', 'dniowiecze']
# 85 [' caryca – ', 'ościuszko"']
# 96762 ['thumb|225p', 'zne w Azji']
# 9835 ['thumb|Pols', ' Wikipedii']
# 6177 ['thumb|300p', 'zne Afryki']
# 1529 ['Cahokia (p', 'c Landmark']
# 67905 ['thumb|300p', 'm\n\n Uwagi ']
# 1535 ['Cristóbal ', 'rli w 1676']
# 1234 ['City – cen', 'gia miasta']
# 5686 ['Człowiek (', ' Linneusza']
# 7610 ['mały|250px', 'body \n \n\n ']
# 16 ['REDIRECT K', 'CT Kryspus']
# 19 ['REDIRECT D', 'Dioklecjan']
# 4460 ['thumb|240p', 'z XX wieku']
# 1179 ['250px|righ', 'Chromosomy']
# 488 ['cps ( – li', 'omputerowy']
# 5370 ['thumb|Blok', 'krownictwo']
# 5918 ['thumb|Czap', 'ski\nKraków']
# 2903 ['thumb|Dzie', 'a fizyczna']
# 3270 ['thumb|240p', 'lu Copleya']
# 924 ['thumb|Brac', 'todoksyjny']
# 644 ['thumb|180p', ' judaizmem']
# 566 ['Costa de l', 'eża Europy']
# 3785 ['Costa del ', 'eża Europy']
# 385 ['thumb|Cost', 'eża Europy']
# 368 ['Costa del ', 'eża Europy']
# 1863 ['thumb|250p', 'eża Europy']
# 1781 ['Costa Brav', 'eża Europy']
# 249 ['Costa Vasc', 'eża Europy']
# 190 ['Costa Mont', 'eża Europy']
# 1517 ['thumb|350p', 'eża Europy']
# 1183 ['mały|prawo', 'eża Europy']
# 596 ['Costa de P', 'eża Europy']
# 1952 ['thumb|Cieś', 'rawo morza']
# 16218 ['Chmielaki ', 'snymstawie']
# 2130 ['thumb|1 ce', 'y zdawkowe']
# 1371 ['thumb|Fran', 'y zdawkowe']
# 2125 ['thumb|Braz', 'a Kolumbii']
# 400 ['Miejscowoś', 'też: colón']
# 34175 ['thumb|Pomn', 'e w Polsce']
# 15 ['REDIRECT C', 'ECT Cherub']
# 768 [' Carmen – ', 'a muzyczna']
# 41518 ['Così fan t', 'ku włoskim']
# 22002 ['Cyganeria ', 'ku włoskim']
# 28 ['Witamy Cza', 'kipedystę.']
# 46236 ['mały|Uwert', 'e Artykuły']
# 35473 ['Czarodziej', 'niemieckim']
# 5919 ['CorelDRAW ', 'wektorowej']
# 1834 ['Borys Fiod', 'rli w 1605']
# 2028 ['Dymitr car', 'rawosławną']
# 2005 ['mały|Pierw', 'isma.\n \n\n*']
# 2960 ['Czasław, C', 'łowiańskie']
# 24 ['REDIRECT I', 'y Oziewicz']
# 145 [' Charon – ', 'a muzyczna']
# 1739 ['thumb|250p', ' księżyców']
# 4294 ['Charon (Pl', 'yte w 1978']
# 3658 ['Charon – z', 'icmetalowe']
# 18 ['REDIRECT K', ' Karakalla']
# 23697 ['thumb|30 S', 'twa Anglii']
# 863 ['Ujednoznac', '2005 (CET)']
# 6163 ['thumb|Opac', 'y w Anglii']
# 36734 ['Czeka, CzK', ' specjalne']
# 2257 ['Chlorek so', ' sole sodu']
# 8810 ['thumb|Kost', 'Słodycze\n ']
# 1487 ['Cota Coca ', ':Кота-Кока']
# 4776 ['Cefeusz (ł', 'zypisy \n\n ']
# 5355 ['Centaur (ł', ' Guide \n\n ']
# 3563 ['Cyrkiel (ł', 'afia \n \n\n ']
# 2428 ['mały|Zbiór', 'не парадку']
# 8947 ['Choroba He', ':Pediatria']
# 2166 ['CORBA () –', 'amistyczne']
# 290 ['Co-NP-zupe', 'złożoności']
# 20 ['REDIRECT C', 'ailifoquan']
# 4951 ['thumb|250p', 'tuki walki']
# 10008 ['mały|uprig', ' w Europie']
# 18235 ['W Czechosł', 'Jugosławia']
# 73 [' cenzor – ', 'ik cenzury']
# 1085 ['Cytologia ', 'enetics\n\n ']
# 70 ['Witaj na P', '--Youandme']
# 11060 ['thumb|300p', ' \n \n \n \n\n ']
# 9782 ['Ciąg – prz', 'quences\n\n ']
# 1440 ['Clarion – ', 'bazodanowe']
# 1441 ['Podział cy', '012 (CEST)']
# 3008 ['Ceres (Cer', ' planetoid']
# 6369 ['Choroba po', 'na zdrowie']
# 1922 ['Chlorowodó', 'zki chloru']
# 18932 ['Chełmno ()', 'XIII wieku']
# 15 ['REDIRECT s', 'ECT sinice']
# 6674 ['Dermatolog', ' lekarskie']
# 722 ['Diabetolog', 'ogiczny\n\n ']
# 848 ['mały|300px', 'amistyczne']
# 4818 ['Dobra publ', 'oria:Dobra']
# 8642 ['Dobro – je', 'oria:Etyka']
# 898 ['Dobra (l.p', 'entarne\n\n ']
# 2927 ['Dowodzenie', 'ozumowanie']
# 356 ['Dziedzina ', 'tematyczna']
# 1765 ['Dieny – gr', 'zypisy \n\n ']
# 4841 ['thumb|300p', 'afia \n \n\n ']
# 2056 ['thumb|Dryf', ' i osprzęt']
# 1298 ['Dehydroepi', 'rosteroidy']
# 1856 ['mały|200 p', 'eki Wschód']
# 1864 ['thumb|Prze', 'a:Roztwory']
# 981 ['Doskład – ', 'egoria:DTP']
# 2118 ['thumbnail|', 'olekularna']
# 31258 ['thumb|Wzór', 'ą fenylową']
# 6031 ['Dowód – wy', 'matematyki']
# 7382 ['thumb|100p', 'inuksa \n\n ']
# 20200 ['Debian (wy', 'e ISO.)\n\n ']
# 45204 ['Dania () –', ':Królestwa']
# 1568 ['Bezpośredn', 'e pamięcią']
# 1698 ['Dżul (J) (', 'od nazwisk']
# 405 ['Doktryna (', ' ideologia']
# 2224 ['thumb|300p', 'tematyczne']
# 14913 ['Druga zasa', 'modynamiki']
# 12647 ['Demografia', ' . Pdf.\n\n ']
# 5586 ['Dewon – te', ' \n \n \n \n\n ']
# 7947 ['Dante Alig', 'y politycy']
# 19892 ['thumb|Mani', ' światowej']
# 899 [' () – usta', 'dnoczonych']
# 5625 ['Dobór natu', 'a:Ewolucja']
# 11545 ['mały|Wszys', 'ograficzne']
# 3540 ['Dębik ośmi', ' Linneusza']
# 432 [' – algoryt', 'ezstratnej']
# 2507 ['Dyskretna ', 'e sygnałów']
# 6811 ['mały|Teori', 'iologiczne']
# 911 ['Dodawanie ', 'macierzach']
# 1905 ['Diagonaliz', 'y macierzy']
# 26 ['REDIRECT I', 'a światowa']
# 7201 ['Dakota Poł', 'dnoczonych']
# 7207 ['Dakota Pół', 'dnoczonych']
# 10876 ['Delaware (', 'dnoczonych']
# 5786 ['thumb|Obra', 'temy wideo']
# 1792 ['thumb|200p', '#DVD-Video']
# 873 ['thumb| Ści', 'ki dźwięku']
# 25 ['REDIRECT D', 'm Woronoja']
# 53 ['REDIRECT A', 'a „duże Ο”']
# 930 ['Dalriada (', 'l and Bute']
# 2153 ['thumb|190p', ':Genologia']
# 7494 ['mały|Relac', 'tematyczne']
# 3623 ['thumb|200p', 'rgumentowe']
# 152 [' dyskrymin', 'cja metalu']
# 839 ['Dystans et', 'gia narodu']
# 679 ['Doktryna r', 'ioznawstwo']
# 5030 ['Dżihad (z ', ' religijne']
# 8465 ['thumb|240p', 'oria Dukli']
# 2558 ['thumb|230p', 'nika nieba']
# 1824 ['Dzień – cz', 'stki czasu']
# 50 ['Dukessa - ', 'ne\nbrulion']
# 13 ['REDIRECT A', 'IRECT A/52']
# 39 ['REDIRECTFr', 'ewolucyjny']
# 20330 ['Domain Nam', 'katalogowe']
# 695 ['Dialekty j', 'e dialekty']
# 1840 ['thumb|250p', 'otamologia']
# 1469 ['Dobór grup', 'a:Ewolucja']
# 3758 ['Dobór krew', 'a:Ewolucja']
# 5756 ['Dobór płci', 'ellt urval']
# 12271 ['David Hume', 'rli w 1776']
# 940 ['Device Fil', 'emy plików']
# 656 ['Device Fil', 'emy plików']
# 5254 ['mały|demet', '\nmr:डीमिटर']
# 3610 ['thumb|Dion', 'goria:Wino']
# 25 ['REDIRECT D', 'mmarskjöld']
# 25 ['REDIRECT D', 'mmarskjöld']
# 2655 ['Dag Hjalma', ' Jönköping']
# 549 ['Dobra pryw', 'oria:Dobra']
# 323 ['thumb|Wykr', 'konsumenta']
# 2598 ['Dochód – w', ' finansowe']
# 8903 ['Deficyt bu', ' finansowe']
# 2434 ['Dolar () –', 'r (waluta)']
# 2294 ['dc – uniks', ' skryptowe']
# 541 [' D.C. (Dis', ' komiksowe']
# 30005 ['Definicja ', 'y na Medal']
# 746 ['mały|Tenak', ':Zecerstwo']
# 17 ['REDIRECT D', 'T Domicjan']
# 25 ['REDIRECT D', 'z Julianus']
# 169 [' Druzus St', 'richoptera']
# 3034 ['Domicjan, ', 'i w Rzymie']
# 19608 ['thumb|Podz', 'w IV wieku']
# 563 ['Flavia Dom', ' w I wieku']
# 4810 [' Domitianu', ' III wieku']
# 308 ['Domitius D', ' urodzenia']
# 621 ['Decencjusz', 'arli w 353']
# 15 ['REDIRECT D', 'ECT Druzus']
# 5829 ['Decimus Cl', 'Rzymskiego']
# 23 ['REDIRECT J', 'a Druzylla']
# 4726 ['thumb|Port', 'rli w 1943']
# 1300 ['thumb|Wspó', 'w kulturze']
# 3039 ['thumb|Dziw', 'łowiańskie']
# 6986 ['thumb|Druk', 'afia \n \n\n ']
# 3729 ['Marcus Did', 'arli w 193']
# 12 ['REDIRECT D', 'DIRECT DVD']
# 4960 ['Dieta (z  ', 'zypisy \n\n ']
# 1440 ['DivX – str', 'eki obrazu']
# 751 ['Druzus Mło', 'marli w 23']
# 3134 ['thumb|Dzia', ' \n\n\n \n\n\n\n ']
# 896 ['thumb|300p', 'tyleryjska']
# 1881 ['Domicja Lo', 'w II wieku']
# 741 ['Deka (da) ', ' jednostek']
# 379 ['Decy (d, d', 'isy \n\ndecy']
# 300 ['Decylion –', 'azwy liczb']
# 2432 ['thumb|upri', 'nformatyki']
# 18040 [' Wątpliwoś', 'on Vallez.']
# 1361 [' D – czwar', 'acznienie)']
# 4219 ['thumb|Beli', 'y i demony']
# 646 ['Daleki Wsc', 'a Północna']
# 2327 ['100px|thum', 'stalacyjne']
# 1293 [' dom – bud', 'acz też \n ']
# 9414 ['mały|Pomni', ' łacińskim']
# 18 ['REDIRECT P', ' Parafilia']
# 1053 ['Druk wklęs', 'niki druku']
# 1938 ['Druk płask', 'niki druku']
# 1447 ['thumb|Idea', 'niki druku']
# 8491 ['thumb|Albr', ' graficzne']
# 1213 ['thumb|Dłut', 'stolarskie']
# 3033 ['thumb|Pras', 'ia książki']
# 1651 ['Dongting H', 'oria:Hunan']
# 1668 ['Diadumenia', 'arli w 218']
# 19 ['REDIRECT D', 'Dioklecjan']
# 658 ['Domicjusz ', 'arli w 311']
# 26 ['PATRZ Domi', 'Aleksander']
# 6399 ['thumb|317p', 'afia \n \n\n ']
# 6456 ['Deizm – nu', 'atolicyzmu']
# 463 ['Flavia Dom', ' w I wieku']
# 15 ['REDIRECT B', 'ECT Balbin']
# 20 ['REDIRECT D', 'iadumenian']
# 19 ['REDIRECT D', 'Dioklecjan']
# 19 ['REDIRECT D', 'Dioklecjan']
# 19987 ['mały|Perga', 'sy etyczne']
# 970 ['thumb|300p', 'y rzymskie']
# 119 [' drachma –', 'owa Grecji']
# 14 ['REDIRECT D', 'RECT Denar']
# 14174 ['Denar (łac', 'rne monety']
# 8850 ['mały|Swast', 'etarianizm']
# 3697 ['mały|300x3', 'ote monety']
# 3690 ['thumb|Typo', 's (morbus)']
# 22 ['redirectno', 'ość statku']
# 13360 ['Dżuma (cza', 'rzez owady']
# 56 [' dy – osad', '– kod IATA']
# 882 ['Dirhem (di', ' Zachodnia']
# 594 ['thumb|4 du', 'ote monety']
# 15120 ['Dariusz I ', 'eku p.n.e.']
# 1278 ['Deuter (, ', 'oria:Wodór']
# 26035 ['Daniel Mar', ' Wikipedii']
# 28668 ['Depeche Mo', 'll of Fame']
# 863 ['thumb|250p', ' Pakistanu']
# 3960 ['thumb|Desz', ' 93–94.\n\n ']
# 1698 ['thumb|200p', 'istoryczne']
# 1741 ['Dzikowy sk', 'dniowieczu']
# 803 ['Donald I, ', 'arli w 862']
# 701 ['thumb|300p', 'miar i wag']
# 20 ['REDIRECT D', 'iadumenian']
# 19 ['REDIRECT D', 'Dalmacjusz']
# 11388 ['Dialekt, n', 'e językowe']
# 2148 ['Dolby Surr', ' Logic IIx']
# 937 ['thumb|200p', 'amięci RAM']
# 2339 ['Dydona i E', 'angielskim']
# 3921 ['thumb|Punk', ':Nawigacja']
# 2769 ['Deflacja (', 'a:Inflacja']
# 57967 ['mały|uprig', ' Białorusi']
# 25 ['REDIRECT D', 'z Julianus']
# 1316 ['Departamen', 'tracyjnego']
# 24 ['REDIRECT E', 'ekt śląski']
# 27 ['REDIRECT D', 'atematyka)']
# 3326 ['Donatello,', ' Florencji']
# 772 ['Dedukcja –', 'ozumowanie']
# 7077 ['Dominikana', 'dnoczonych']
# 19646 ['Dwutlenek ', 'enki węgla']
# 985 ['thumb|200p', 't gaśniczy']
# 1307 ['Do ut des ', 'ogia prawa']
# 43392 ['thumb|Dial', 'lozoficzna']
# 858 ['thumb|Deni', 'eni w 1647']
# 122 ['Co książka', '. --Topory']
# 1555 ['Poprawna p', '--Youandme']
# 35406 ['Kalendariu', 'nencie.\n\n ']
# 3993 ['thumb|Sche', 'Taksonomia']
# 3162 [' \n\nmały|Ma', 'ormatyczne']
# 63 ['REDIRECT P', 'amięci RAM']
# 8884 ['Dane osobo', 'zypisy \n\n ']
# 6196 ['Diecezja (', 'o Kościoła']
# 678 ['Endokrynol', 'ogiczne\n\n!']
# 4492 ['Ekonomia –', 'konomiczne']
# 4006 ['thumb|120p', 'zypisy \n\n ']
# 1149 ['Elektrofil', ' chemiczne']
# 850 ['thumb|408p', 'egoria:RNA']
# 28 ['PATRZ Tabe', 'ygraficzna']
# 14179 ['thumb|200p', 'zypisy \n\n ']
# 843 ['thumb|alt=', 'wa 1972\n\n*']
# 9513 ['thumb|Endo', 'oskopia\n\n!']
# 5644 ['Euklides z', 'eku p.n.e.']
# 31815 ['Estonia ()', ' bałtyckie']
# 30454 ['mały|uprig', ' Wielkiego']
# 2182 ['Energia we', 'ia:Energia']
# 814 ['ECS ( – ul', 'oria:Amiga']
# 16 ['PATRZ Euka', 'Eukarionty']
# 16 ['PATRZ Euka', 'Eukarionty']
# 1974 ['Etnocentry', ' kulturowa']
# 2197 ['Energia sw', 'ne od osób']
# 5254 ['Entalpia (', 'ia:Energia']
# 539 ['Ewolucja –', '01 roku\n\n ']
# 3757 ['Edward Osb', ' (Alabama)']
# 103 [' ewolucjon', 'olityczna)']
# 27 ['PATRZtabel', 'ygraficzna']
# 3646 ['Era kenozo', 'neogenu\n\n ']
# 4314 ['Era mezozo', 'afia \n \n\n ']
# 18 ['REDIRECT P', ' Paleozoik']
# 19481 ['thumb|Euge', 'schodniego']
# 65566 ['mały|200px', 'y na Medal']
# 21333 ['Erwin Joha', 'rli w 1944']
# 10576 ['Entropia (', 'kcje stanu']
# 1227 [' – założon', 'non-profit']
# 1045 ['Etnogeneza', 'gia narodu']
# 3920 ['Elektrouje', 'a fizyczna']
# 27 ['REDIRECTEr', ' Karlfeldt']
# 2646 ['Eugene Gla', 'rli w 1953']
# 9474 ['thumb|300p', 'rzne \n \n\n ']
# 1378 ['Etologia (', 'sychologia']
# 45718 ['thumb|Flag', 'y na Medal']
# 8850 ['Europejski', ' nad Menem']
# 3065 ['Epika (gr.', ':Genologia']
# 1746 ['Egzogamia ', 'Małżeństwo']
# 1857 ['Endogamia ', 'Małżeństwo']
# 12 ['PATRZ Eryd', 'TRZ Erydan']
# 608 ['Efekt mnoż', 'ier effect']
# 911 ['Epoka pale', 'nologiczne']
# 6428 ['Edward Jan', 'acy w Peru']
# 2944 ['thumb|Hist', 'rli w 1919']
# 4277 ['thumb|Popi', ' planetoid']
# 1960 ['Edgar Doug', 'oyal Medal']
# 10296 ['thumb|300p', 'Theory \n\n ']
# 4234 ['Elia Kazan', 'rli w 2003']
# 1568 ['thumb|420p', 'zypisy \n\n ']
# 10068 ['mały|Insta', 'rmalna?\n\n ']
# 21257 ['Eurypides ', '406 p.n.e.']
# 26 ['PATRZ Pocz', 'ktroniczna']
# 29 ['REDIRECT P', 'ktroniczna']
# 35544 ['Ernest Mil', 'rli w 1961']
# 7857 ['Erich From', 'rli w 1980']
# 2089 ['Eric Steve', 'w Bostonie']
# 5463 ['Etnografia', 'tropologii']
# 6101 ['thumb|240p', 'rli w 1976']
# 2148 ['Empiryzm (', 'sychologii']
# 8701 ['Elektron, ', 'ia:Leptony']
# 2208 ['Eugenio Mo', 'rli w 1981']
# 4959 ['thumb|"Śle', 'rli w 1994']
# 31 ['REDIRECT O', 'akowe SGML']
# 1283 ['eMac – kom', 'oku.\n\neMac']
# 199 ['Nie wiem, ', ' \n--Matusz']
# 15 ['REDIRECT A', 'ECT Awitus']
# 579 ['Eudoksja (', 'na greckie']
# 117 [' Eudoxia (', ' Przypisy ']
# 31725 ['Enya, właś', 'i w 1961\n ']
# 6278 ['thumb|Uder', 'namiczne\n ']
# 886 ['Emisja – w', 'a\n audycja']
# 6797 ['Emilian – ', ' łacińskie']
# 461 ['Eksa (E) –', ' jednostek']
# 1770 ['right|100p', 'oliterowy.']
# 448 ['Ewrotas, d', 'Egejskiego']
# 14 ['patrzeksli', 'zekslibris']
# 35 ['REDIRECTHe', 'z rzymski)']
# 3116 ['Flawiusz E', 'w IV wieku']
# 3140 ['Eugeniusz ', 'na greckie']
# 1698 ['thumb|300p', 'łtyckie\n\n ']
# 2243 ['mały|240px', 'zypisy \n\n ']
# 8530 ['mały|Europ', ' 2013\n \n\n ']
# 2220 ['thumb|Mapa', 'ony Europy']
# 5087 ['thumb|Euro', 'nym ONZ\n\n ']
# 3826 ['thumb|300p', 'zypisy \n\n ']
# 9736 ['Era kalend', 'lendarzowe']
# 24 ['REDIRECT J', ' baskijski']
# 744 ['Elektron –', 'ria:Magnez']
# 7796 ['thumb|290p', ' Jądrowych']
# 3441 ['Ewa – imię', 'a semickie']
# 324 ['Er lub er:', 'do Erytrei']
# 498 [' .es – dom', 'teboardowe']
# 455 [' Unia Euro', 'niwersalny']
# 22 ['REDIRECT S', 'Kościuszko']
# 22 ['REDIRECT S', 'Kościuszko']
# 198 [' Europejsk', 'd formula)']
# 11069 ['Efedryna –', 'nie czynne']
# 614 [' elf – stw', 'kańskiego)']
# 2835 ['Skrajnie n', 'agnetyczne']
# 2427 ['Emil Abder', 'rli w 1950']
# 28762 ['Eutanazja ', 'ia:Grzechy']
# 1759 ['mały|Zdjęc', 'Fotografia']
# 19813 ['Władcy Egi', ' \n\n \nEgipt']
# 7456 ['Emacs – ro', 'pisane w C']
# 3402 ['thumb|170p', 'ormatyczny']
# 17 ['REDIRECT e', 'T emotikon']
# 591 ['thumb|GNU ', 'teligencji']
# 10372 ['mały|Certy', 'ormatyczna']
# 778 [' \nmały|Map', 'konomiczna']
# 3423 ['Amalie Emm', 'egenci ICM']
# 10391 ['Évariste G', 'we Francji']
# 1157 ['thumb|150p', 'zypisy \n\n*']
# 1128 ['Efekt Schw', 'Fotografia']
# 57085 ['Elbląg (, ', 'pospolitej']
# 2448 ['Elbląg (ni', ' Wiślanego']
# 22 ['redirect A', 'ropogeneza']
# 28 ['REDIRECT N', 'Demokracja']
# 36 ['REDIRECT H', 'z rzymski)']
# 1037 ['thumb|250p', 'literackie']
# 9919 ['mały|Homer', 'poematów\n ']
# 952 ['right|230p', 'zeni w 401']
# 2160 ['Eurazja (n', 'fia Europy']
# 7421 ['thumb|C je', 'e enclaves']
# 17077 ['thumb|C je', 'a:Eksklawy']
# 2061 ['Wartościow', ' funkcyjne']
# 32 ['REDIRECTwa', ' zachłanne']
# 9686 ['Etyka (z ,', '\n\n \n \n \n\n!']
# 7347 ['Europejski', 'ospodarcze']
# 2386 ['Europejski', 'ólne rynki']
# 32736 ['Epistemolo', 'jących.\n\n ']
# 1494 ['Efekt Eliz', 'teligencja']
# 2298 ['thumb|240p', 'li z głodu']
# 2224 ['errno – un', 'goria:Unix']
# 9530 ['mały\nEmpat', 'ospołeczne']
# 3434 ['Eksperymen', 'ty naukowe']
# 1240 ['thumb|Elek', 'a 2006.\n\n ']
# 3322 ['thumb|220p', 'wa światła']
# 8121 ['thumb|280p', 'Mieszaniny']
# 9361 ['Epikur (gr', ' samobójcy']
# 4744 ['thumb|Mode', 'ocykliczne']
# 14 ['PATRZ Bakt', 'Z Bakterie']
# 580 ['Elektronic', 'ktroniczny']
# 24 ['PATRZ Gruź', ' człowieka']
# 5753 ['thumb|Czte', 'oria filmu']
# 9196 ['thumb|Od g', 'ia cyfrowa']
# 22 ['REDIRECT z', 'ór wypukły']
# 25 ['redirect P', ' de Fermat']
# 2069 ['Funkcja zd', 'tematyczna']
# 25 ['REDIRECT F', 'a zdaniowa']
# 1845 ['thumb|Przy', 'eglarstwo)']
# 954 ['thumb|Stat', ':Nawigacja']
# 19283 ['mały|Herra', 'icon.\n \n\n ']
# 53348 ['Fryderyk F', 'rli w 1849']
# 21 ['PATRZ Fryd', 'ryk Chopin']
# 11 ['redirectga', 'edirectgaz']
# 14 ['redirect C', 'rect Ciecz']
# 965 ['thumb|300p', 'zypisy \n\n ']
# 443 ['150px|thum', 'gia morska']
# 7295 ['Francis Dr', 'h na Ziemi']
# 4914 ['Jean-Franç', 'rli w 1788']
# 965 ['Fotoskład ', 'nie tekstu']
# 1741 ['thumb|Ferm', 'afia \n \n\n ']
# 8366 ['thumb|Kuli', 'rodą Nobla']
# 8803 ['thumb|Frak', 'etryczne\n ']
# 14425 ['mały|To, c', '. Firka\n\n ']
# 9324 ['FreeBSD – ', 'operacyjne']
# 3500 ['Protokół t', ' aplikacji']
# 31722 ['Finlandia,', ' nordyckie']
# 7590 ['Fluor (F, ', ' chemiczne']
# 9143 ['thumb|upri', 'zypisy \n\n ']
# 1579 ['Funkcja st', 'zypisy \n\n ']
# 14138 ['Friedrich ', 'rli w 1957']
# 8867 ['thumb|Wido', 'g HINT)\n\n ']
# 1290 ['Falki () –', 'ne AGH)\n\n ']
# 411 ['thumb|250p', 'a).\n\nHaara']
# 11552 ['thumb|Insy', 'monarsze\n\xa0']
# 737 ['thumb|Przy', 'puterowych']
# 1326 ['thumb|100p', 'ne Niemiec']
# 1562 ['thumb|250p', 'oria:Facje']
# 2766 ['Firet – po', 'raficznych']
# 3494 ['Jean Frédé', 'rli w 1958']
# 1049 [' coraz chł', '2015 (CET)']
# 7694 ['thumb|Pros', ' zespolona']
# 659 ['Funkcja (ł', ' „funkcje”']
# 23985 ['mały|Funkc', '12-23].\n\n ']
# 177 [' Floryda –', ' \n Florida']
# 2783 ['thumb|Fras', 'literackie']
# 463 ['FUD ( „str', ' społeczna']
# 21 ['REDIRECT R', 'by (znaki)']
# 7637 ['Frank Herb', 'rli w 1986']
# 48 [' Francis B', 'n (malarz)']
# 11033 ['Frank Lloy', 'órcy mebli']
# 10949 ['Floryda (,', 'dnoczonych']
# 3729 ['thumb|Fale', 'ejsmologia']
# 17506 ['thumb|Fran', ' wydań)\n\n ']
# 8856 ['Fortran (o', 'ndardy ISO']
# 8409 ['Fritz Habe', 'rli w 1934']
# 1445 ['FAQ ( – cz', 'nternetowa']
# 12472 ['FidoNet – ', 'ard System']
# 468 ['thumb|Aleg', 'olucyjnego']
# 330 ['Fortunki (', 'goria:Unix']
# 8253 ['Felix Chri', 'rli w 1925']
# 3035 ['Frans Eemi', 'rli w 1964']
# 4255 ['Frankowie ', 'wo Franków']
# 4580 ['mały|240px', ' Florencji']
# 6000 [' Strony pr', '014 (CEST)']
# 2116 ['FFTW () – ', 'e sygnałów']
# 14097 ['Fantasy – ', 'Fantastyka']
# 20 ['REDIRECT F', 'an fiction']
# 20 ['REDIRECT F', 'an fiction']
# 6191 ['Foton (gr.', 'ria:Bozony']
# 1995 ['Fermiony (', 'zypisy \n\n ']
# 17 ['PATRZ Live', 'ive action']
# 18209 ['thumb|Przy', '\nAnimowany']
# 22 ['PATRZKlatk', 'na sekundę']
# 854 ['right|200p', ' \n \n \n \n\n ']
# 6342 ['thumb|240p', 'ołudniowej']
# 2540 ['thumb|350p', ':Postpress']
# 1609 ['Fakt – zai', ':Ontologia']
# 46 ['redirect Z', 'iszkańskie']
# 783 [' (proste ś', ':Rendering']
# 583 ['left|thumb', 'nego Rzymu']
# 1855 ['Florian – ', ' łacińskie']
# 502 ['300px|thum', ':Rendering']
# 4434 ['Filip I Ar', 'a:Arabowie']
# 17 ['REDIRECT S', 'T Sewer II']
# 922 ['mały|prawo', 'kiennictwo']
# 5038 ['thumb|300p', 'strona \n\n ']
# 611 [' postać wy', 'yna Figura']
# 1425 ['Faustyna M', 'arli w 175']
# Chunk 3 of 8388608 bytes <class 'str'>
# 5054 ['Free Pasca', 'ji GNU GPL']
# 4155 ['Festiwal (', 'zypisy \n\n ']
# 8352 ['Wyjaśnieni', '010 (CEST)']
# 28 ['REDIRECT T', 'z I Wielki']
# 21 ['REDIRECT F', 'lip I Arab']
# 267 ['Femto (f) ', 'sy \n\nfemto']
# 624 ['F (minusku', 'Spółgłoski']
# 15 ['REDIRECT Ż', 'ECT Żelazo']
# 215 ['Flawiusz W', 'w IV wieku']
# 8279 ['thumb|300p', 'e world\n\n ']
# 1068 ['Flaga Arab', 'audyjskiej']
# 1992 ['Flaga Libi', 'dowe Libii']
# 19508 ['Flaga Pols', ' Wikipedii']
# 4002 ['Flaga Irla', 'e Irlandii']
# 824 ['thumb|250p', 'dowe Nauru']
# 4469 ['thumb|Szta', 'i\nBrazylii']
# 1006 ['thumb|Pols', 'zypisy \n\n ']
# 2611 ['Flaga olim', 'limpijskie']
# 71 ['REDIRECT M', 'ółksiężyca']
# 2122 ['thumb|Flor', ' Florencji']
# 1434 ['thumb|240p', 'ria:Monety']
# 497 [' fm – jedn', ' Przypisy ']
# 11 ['PATRZ Fran', 'ATRZ Frans']
# 2929 ['thumb|Prze', 'e sygnałów']
# 1287 ['mały|Holen', 'polityczna']
# 21 ['REDIRECT F', 'le krótkie']
# 1654 ['Fale średn', 'agnetyczne']
# 21 ['REDIRECT f', 'le średnie']
# 2187 ['Fale długi', 'agnetyczne']
# 20 ['REDIRECT f', 'ale długie']
# 1881 ['ŚF. Czy  r', '2014 (CET)']
# 3066 ['mały|Wzorz', 'miar i wag']
# 3300 ['thumb|150p', 'agnetyczne']
# 24 ['PATRZ Fale', 'dzo długie']
# 1674 ['Fale decym', 'agnetyczne']
# 540 ['Fale centy', 'agnetyczne']
# 327 ['Fale milim', 'agnetyczne']
# 755 ['Fale submi', 'agnetyczne']
# 847 ['Finowie (f', 'ko-fińskie']
# 37484 [' Początek ', 'pisy \n\n \n*']
# 5564 ['mały|Wzór ', 'Prebiotyki']
# 3088 ['thumb|Nada', 'iotechnika']
# 34 ['REDIRECT K', 'z rzymski)']
# 33 ['REDIRECT G', 'z rzymski)']
# 33 ['REDIRECT F', 'z rzymski)']
# 44726 ['Franz Uri ', 'eni w 1858']
# 1782 ['Francis Ha', 'oyal Medal']
# 11 ['PATRZ Flej', 'ATRZ Flejm']
# 111 [' Jean Bapt', 'a utopijny']
# 1367 ['Faust – im', ' łacińskie']
# 1147 ['Friedrich ', 'lu Copleya']
# 1216 ['Farad (F) ', 'od nazwisk']
# 24 ['REDIRECT F', 'ois Villon']
# 15740 ['Chopin czy', 'n.p.\n\n\n\n\n\n']
# 899 ['François D', 'w Brukseli']
# 27 ['PATRZ Plau', 'cesarzowa)']
# 685 [' Edward Fi', 'la Ludwika']
# 17349 ['Ferdynand ', 'a Pacyfiku']
# 360 [' Faustyna ', 'kaszewicza']
# 6783 ['mały|Okład', 'ki filmowe']
# 4100 ['Ford FT-B ', ' z lat 20.']
# 5294 ['Federacja ', 'Brytanii\n ']
# 534 ['Francuskie', 'ie kolonie']
# 47734 ['thumb|Niet', 'y na Medal']
# 8457 ['thumb|Skam', 'os.com \n\n ']
# 1111 [' Istoty mi', 'x\n Phoenix']
# 764 ['Fałsz – je', 'ria:Prawda']
# 6551 ['Funkcja Ac', 'a obliczeń']
# 2433 ['Francis Pi', 'rli w 1953']
# 497 ['180px|thum', 'hile\nChile']
# 498 ['Flex (The ', 'Kompilacja']
# 893 ['thumb|120p', 'w II wieku']
# 10310 ['Florencja ', ' Florencja']
# 14910 ['Fentanyl (', 'ksykologia']
# 60365 ['thumb|250p', 'otosynteza']
# 6688 ['Drobna uwa', '017 (CEST)']
# 3264 ['Fluorowodó', 'owcowodory']
# 9072 ['Fosforowod', 'zki wodoru']
# 20 ['REDIRECTfo', 'sforowodór']
# 20965 ['Ta strona ', '- archiwum']
# 510 [' Grzegorz ', '2007 (CET)']
# 770 ['Gastroente', ' lekarskie']
# 2316 ['thumb|Wzie', ' lekarskie']
# 3716 [' () – lice', 'egoria:GNU']
# 26 ['REDIRECT G', 'nterologia']
# 13747 ['mały|Sekwe', 'tematyczna']
# 2210 ['Grupa funk', 'zypisy \n\n ']
# 1714 ['thumb|Cząs', '\n\nAlkilowa']
# 1746 ['mały|2020 ', 'z XX wieku']
# 6355 ['thumb|240p', 'z XX wieku']
# 7262 ['Glicyna ()', 'rzekaźniki']
# 3471 ['Gaz – stan', 'zyka gazów']
# 1194 ['Genotyp (g', 'a:Genetyka']
# 6156 ['George Ber', 'rli w 1950']
# 3786 ['thumb|Graz', 'rli w 1936']
# 8373 ['thumb|240p', 'rli w 1880']
# 13421 ['thumb|250p', 'y miejskie']
# 13430 ['thumb|350p', ' Polski\n\n ']
# 980 ['Cykliczne\n', '2 lis 2001']
# 4290 ['Wydaje mi ', '015 (CEST)']
# 4873 ['Glukoza, D', 'ldoheksozy']
# 4781 ['Helowce, g', 'hemicznych']
# 1679 [' góra – fo', 'ż \n Góry\n ']
# 24958 ['mały|Przyk', '05-10].\n\n ']
# 1560 ['thumb|250p', 'ia rozrodu']
# 6179 ['thumb|Obra', 'ia)\n \n \n\n ']
# 46682 ['Grupa – st', 'działaniem']
# 2667 ['GNU/Linux ', 'oria:Linux']
# 6603 ['thumb|Herb', 'XVII wieku']
# 30294 ['thumb|Chat', ' Wikipedii']
# 28146 ['thumb|upri', 'ołudniowej']
# 2383 ['Gaz doskon', 'zyka gazów']
# 1290 ['GusGus – z', 'tronicznej']
# 5991 ['Geografia ', 'ia \n \n \n\n ']
# 1528 ['GNU Scient', 'pisane w C']
# 35 ['REDIRECT G', 'ic License']
# 17317 ['thumb|240p', 'eni w 1946']
# 6311 ['Giorgione,', 'rli w 1510']
# 8078 ['Giotto di ', 'XIII wieku']
# 6365 ['GNU Compil', 'egoria:GNU']
# 345 ['Glacjologi', 'zypisy \n\n ']
# 16342 ['Co do gwar', '012 (CEST)']
# 8101 ['Glin (w te', 'organiczne']
# 12441 ['System inf', 'orskiej\n\n ']
# 19479 ['Gwatemala ', ' Północnej']
# 304 ['Gawra (z \n', 'a:Etologia']
# 993 ['Geografia ', 'afia \n \n\n ']
# 17189 ['mały|Grań ', 'ych państw']
# 31 ['PATRZ Ziem', 'agnetyczne']
# 1168 ['Polimerek ', 'sji.\n--Taw']
# 2809 ['Groty Mech', ' pomorskim']
# 1024 ['thumb|Mapa', ':Listy gór']
# 4321 ['Gniewosz p', ' 1768 roku']
# 6728 ['thumb|Cono', 'ogy\n \n \n\n ']
# 5773 ['Geografia ', 'zypisy \n\n ']
# 9753 ['Grupa prze', '-05].\n\n \nP']
# 744 ['Geografia ', 'tologia\n\n ']
# 758 ['Geografia ', 'konomiczna']
# 1663 ['Geografia ', 'konomiczna']
# 5711 ['Geronimo w', 'rli w 1909']
# 1717 ['Gustav Ado', 'rli w 1943']
# 736 ['Geografia ', 'nistyka\n\n ']
# 13018 ['thumb|Pomn', 'dnoczonych']
# 2321 ['mały|KDE P', 'Interfejsy']
# 3807 ['mały|240px', 'rmański\n\n ']
# 11130 ['thumb|Grup', 'gia narodu']
# 556 ['Geografia ', 'biorstw\n\n ']
# 13 ['REDIRECT G', 'IRECT Goci']
# 16 ['REDIRECT S', 'CT Sekwoja']
# 7009 ['Giewont – ', 'Zachodnich']
# 13753 ['thumb|Wnęt', 'polityczna']
# 105763 ['thumb|Słoń', '09-20].\n\n ']
# 21 ['REDIRECT g', 'iazdozbiór']
# 4143 ['Góra Stoło', 'zypisy \n\n ']
# 275 ['Zacząłem o', 'ęcej.Kpjas']
# 17409 ['George Was', 'a monetach']
# 6035 ['thumb|350p', 'ject\xa0\n\n\n\n ']
# 3432 ['thumb|Gran', ' państwowa']
# 700 ['thumb|left', 'zypisy \n\n ']
# 4086 ['Galen, wła', 'w II wieku']
# 3856 ['Gustaw I W', ' Finlandii']
# 7371 ['Guru (dewa', 'hinduizmie']
# 1417 ['thumb|Zest', ' malarskie']
# 19833 ['thumb|Szwe', 'rli w 1632']
# 9095 ['Gustaw IV ', ' Finlandii']
# 7224 ['Gustaw III', 'rli w 1792']
# 1408 ['thumb|240p', 'ki Kadyksu']
# 2541 ['Gwadiana (', 'raniczne\n ']
# 1567 ['Gwajakowie', ' Linneusza']
# 856 ['Graf pełny', 'sy \n\npełny']
# 705 [' graf (mat', 'eż \n Graff']
# 292 ['Gzikowate,', 'ia:Gzowate']
# 163 [' Gzy (Oest', ' – gromada']
# 1159 ['right|thum', 'y Index\n\n!']
# 28318 ['Georg Frie', 'insterskim']
# 2788 ['Grzbiet Ha', 'podmorskie']
# 2536 ['thumb|Aven', 'rli w 1891']
# 10430 ['Gerhart Jo', 'rzed 1945)']
# 545 ['Gongoryzm ', 'literackie']
# 318 ['Goniony – ', 'ńce ludowe']
# 28491 ['mały|Stary', 'pospolitej']
# 19029 ['thumb|Gabr', 'rli w 1922']
# 961 ['Geologia h', 'rzne \n \n\n ']
# 177 [' Germinal ', ' 1993 roku']
# 688 ['Geografia ', 'konomiczna']
# 1886 ['W ency nie', 'tek wpisu?']
# 42170 ['Gajusz Jul', 'y na Medal']
# 64069 ['Gwinea Rów', 'a w Afryce']
# 7375 ['Gabriela M', 'lnomularze']
# 10556 ['thumb|Graf', 'zypisy \n\n ']
# 1183 ['mały|Zrzut', 'ompilatory']
# 777 ['GNU Visual', ' programów']
# 28 ['REDIRECT G', 'l Debugger']
# 18529 ['Genetyka (', '\n \n\n \n \n\n ']
# 1627 ['GNU Multip', 'pisane w C']
# 351 [' guanozyno', 'ic Library']
# 9123 ['thumb|250p', 'zypisy \n\n ']
# 115624 ['thumb|upri', ' Wikipedii']
# 10599 ['George Ber', 'w Dublinie']
# 2742 ['mały|Goldw', 'nia polska']
# 7658 ['thumb|Pros', 'zypisy \n\n ']
# 9573 ['thumb|Gala', 'xy Zoo \n\n ']
# 5193 ['mały|prawo', 'zypisy \n\n ']
# 487 [' Gothic – ', 'ra gotycka']
# 10995 ['mały|Diagr', 'a kwantowa']
# 1927 ['thumb|Symb', 'a kwantowa']
# 830 ['Oświetleni', 'omputerowa']
# 6896 ['thumb|350p', 'azowsza\n\n ']
# 297 ['Geografia ', 'konomiczna']
# 2539 ['Geografia ', 'rzne \n \n\n ']
# 6811 ['Gabriel Jo', 'rli w 2014']
# 4567 ['mały|prawo', 'amistyczne']
# 13846 ['mały|240px', 'a:Alfabety']
# 6543 ['Galba, wła', 'marli w 69']
# 17 ['REDIRECT G', 'T Germanik']
# 4736 ['Gaius Clau', 'marli w 19']
# 3087 ['Geta (ur. ', 'i w Rzymie']
# 18 ['REDIRECT G', ' Galeriusz']
# 1259 ['Gordian I,', 'arli w 238']
# 21568 ['mały|Gorli', 'skid Niski']
# 2286 ['Galienus, ', 'onarchowie']
# 1674 ['Gliceriusz', ' w V wieku']
# 141 [' Święty Gl', 'Sługa Boży']
# 379 ['Gordian II', 'arli w 238']
# 5716 ['Gordian II', 'arli w 244']
# 4212 ['Gęstość op', 'Absorbance']
# 2837 [' \n\nGaleriu', 'arli w 311']
# 6366 ['mały|Były ', 'nnecticut)']
# 2147 ['GIF () – f', 'raficznych']
# 1761 ['Greting (a', ' i osprzęt']
# 12679 ['mały|Upusz', 'podstawowe']
# 24362 ['Gady (Rept', '\n \n \n\n \n\n ']
# 1920 ['Georg Simo', ' Monachium']
# 2690 ['Gracjan, G', 'ntyniańska']
# 16 ['REDIRECT G', 'CT Gracjan']
# 558 ['Giga (G) –', ' jednostek']
# 857 ['Gramatura ', 'ria:Papier']
# 8560 ['GIMP () – ', 'pisane w C']
# 859 ['Gram, ozna', 'nostki CGS']
# 716 ['right|100p', 'noliterowy']
# 9168 ['thumb|250p', ' planszowe']
# 70206 ['mały|Gdańs', 'pospolita)']
# 560 ['Galeon – p', 'oria:GNOME']
# 1736 ['Gwiazda Po', 'a astralne']
# 445 [' Gwiazda W', 'da Poranna']
# 145 ['Garlino-Ra', 'ia:Garlino']
# 715 [' Gal – pie', 'a-2 Gabonu']
# 317 [' german – ', 'z rosyjski']
# 46274 ['mały|Rzeka', 'XIII wieku']
# 61052 ['mały|Gorzó', 'ch powiatu']
# 53805 [' (, Graude', ' Grunwaldu']
# 8640 ['Gregor Joh', 'cy sudeccy']
# 14520 ['Georg Frie', 'i w 1866\n ']
# 3412 ['thumb|250p', 'zypisy \n\n!']
# 15 ['REDIRECT G', 'ECT Galien']
# 149 [' Gordian I', 'mię męskie']
# 7931 ['Grafika we', 'omputerowa']
# 2361 ['thumb|200p', 'iturgiczne']
# 20 ['REDIRECT G', 'ordian III']
# 64152 ['thumb|Zapi', ' stołeczne']
# 11 ['REDIRECT k', 'EDIRECT k2']
# 267 ['Giaur (tur', ' w islamie']
# 1624 ['Goj (z heb', 'ia:Judaizm']
# 816 ['Gulden – m', 'e monety\n ']
# 3472 ['Grunwald (', 'ld (gmina)']
# 28 ['REDIRECT T', 'ator Tesli']
# 1754 ['thumb|200p', 'kie monety']
# 6 ['TAM GD', 'TAM GD']
# 310 [' GG – kod ', 'a Gubernia']
# 8633 ['GG (dawnie', 'nternetowe']
# 26 ['Witamy na ', 'dii. --Taw']
# 51866 ['Gdynia (, ', 'w XX wieku']
# 1576 ['thumb|240p', ':Rzemiosło']
# 3288 ['Gruszczyce', 'rzne \n \n\n*']
# 562 [' – słowa w', 'k japoński']
# 4087 ['Geografia ', ':Rolnictwo']
# 5466 ['thumb|Gasp', 'rli w 1624']
# 45 ['REDIRECT S', 'czywistego']
# 13391 ['mały|Tales', 'terowych\n ']
# 5802 ['thumb|200p', 'su wolnego']
# 18 ['REDIRECT G', ' Galeriusz']
# 10080 ['thumb|240p', 'sce w 1930']
# 295 [' Gal – met', 'y śmierci.']
# 36 ['PATRZ Gdyn', ' Żeglugowe']
# 1611 ['Spuneryzm ', '#Kecskerím']
# 3525 ['Georgia Po', 'łudniowego']
# 3243 ['mały|300px', 'oceaniczne']
# 29938 ['Giordano B', 'a Księżycu']
# 34463 ['Galileusz\n', 'rli w 1642']
# 17791 ['Grudzień 1', 'e w Polsce']
# 8247 ['Giuseppe F', 'i w 1901\n ']
# 7969 ['Gioachino ', 'i w Pesaro']
# 19595 ['George Orw', 'j Brytanii']
# 4042 ['Georges Bi', 'rli w 1875']
# 12344 ['George San', 'rli w 1876']
# 1218 ['Grej (symb', 'ochodne SI']
# 231 ['Francja:\n ', 'owa Gujany']
# 6328 ['thumb|250p', ' Glauberyt']
# 909 ['Giambologn', 'rli w 1608']
# 25 ['REDIRECT T', 'z Kurcyusz']
# 3953 ['mały|272x2', ' czasopism']
# 5118 ['thumb|Port', 'rli w 1375']
# 738 ['mały|Mapa ', 'aman i Diu']
# 15 [' \nGlebozna', 'boznawstwo']
# 2242 ['Gospodarka', 'ia \n \n \n\n ']
# 1315 ['Giovanni P', 'klasycyzmu']
# 25891 ['mały|Tabli', 'ębiorstwo)']
# 7360 ['thumb|150p', 'zypisy \n\n ']
# 4824 ['mały|Ślady', 'ia:Gwiazdy']
# 19167 ['mały|Nagro', 'rli w 1969']
# 6879 ['mały|Pokaz', 'astronomią']
# 31 ['REDIRECT G', 'ich Händel']
# 1883 ['thumb|Gwin', 'ote monety']
# 1896 ['thumb|250p', 'tegoria:Go']
# 1791 ['Gerhard Ge', 'rli w 1945']
# 1091 ['Generator ', 'o Fighters']
# 29671 ['Gottfried ', 'owie prawa']
# 1796 ['Georges Br', 'rli w 1963']
# 7133 ['thumb|Kami', ' Warszawie']
# 5521 ['Georg Ferd', 'rli w 1918']
# 27 ['REDIRECT G', 'a językowa']
# 49813 ['Seria arty', ' Wikipedii']
# 1143 ['Hepatologi', 'epatologia']
# 2032 ['Hematologi', 'jologów\n\n ']
# 24037 [' Trzy trad', 'ilozofii\n!']
# 27670 ['mały|ENIAC', ' \n \n \n \n\n ']
# 402 [' Wydarzeni', 'zenia 1971']
# 778 [' Kalendari', 'zenia 1947']
# 729 [' Kalendari', 'zenia 1957']
# 722 [' Kalendari', 'zenia 1958']
# 646 [' Kalendari', 'zenia 1969']
# 562 [' Kalendari', 'zenia 1972']
# 759 [' Kalendari', 'zenia 1975']
# 436 [' Kalendari', 'zenia 1970']
# 357 [' Kalendari', 'zenia 1946']
# 384 [' Kalendari', 'zenia 1960']
# 676 [' Kalendari', 'zenia 1943']
# 515 [' Kalendari', 'zenia 1973']
# 1061 [' Kalendari', 'zenia 1979']
# 770 [' Kalendari', 'zenia 1974']
# 700 [' Kalendari', 'zenia 1976']
# 850 [' Kalendari', 'zenia 1977']
# 677 [' Kalendari', 'zenia 1978']
# 512 [' Kalendari', 'zenia 1968']
# 324 [' Kalendari', 'zenia 1967']
# 361 [' Kalendari', 'zenia 1966']
# 551 [' Kalendari', 'zenia 1965']
# 1050 [' Kalendari', 'zenia 1964']
# 390 [' Kalendari', 'zenia 1963']
# 543 [' Kalendari', 'zenia 1962']
# 442 [' Kalendari', 'zenia 1961']
# 365 [' Kalendari', 'zenia 1959']
# 729 [' Kalendari', 'zenia 1948']
# 3773 ['SV Herzogi', 'z XX wieku']
# 723 ['300px|righ', 'ia:Koszary']
# 398 ['thumb|Hund', ' i osprzęt']
# 904 ['Hisowanie ', 'zy jachcie']
# 2970 ['Hals – ter', 'żeglarskie']
# 27435 ['Henryk Ada', 'rli w 1916']
# 12975 ['Hugo Dyoni', 'rli w 1972']
# 26905 ['Heroina, d', 'ia:Proleki']
# 17 ['REDIRECT G', 'T GNU Hurd']
# 905 ['Hospitacja', 'ia:Oświata']
# 14 ['REDIRECT H', 'RECT HP-UX']
# 2154 ['Home inter', '(Internet)']
# 7616 ['Unix jest ', 'nformatyki']
# 54486 ['Hiszpania,', 'ołudniowej']
# 26943 ['Holandia (', 'Zachodniej']
# 2336 ['mały|Proto', 'goria:HTTP']
# 6300 ['thumb|280p', 'ródłach\n\n ']
# 511 ['Polska:\n H', 'cniony Hel']
# 22018 ['thumb|280p', 'starożytne']
# 511 ['thumb|Hand', 'eglarstwo)']
# 39512 ['thumb|170p', 'owych\n \n\n ']
# 2361 ['thumb|400p', '1996, .\n\n ']
# 23215 ['Heinz Wilh', 'y na Medal']
# 39778 ['mały|Flagi', ', Historia']
# 7872 [' Kalendari', 'zypisy \n\n ']
# 11641 ['HTML (, hi', 'bmastering']
# 5165 ['mały|Zapyt', 's HTTP \n\n*']
# 179 [' Booker Hu', 'ka aktorka']
# 59 ['PATRZ nazi', 'ne od osób']
# 15579 ['thumb|Pols', '69-1792\n\n ']
# 83742 ['Humphrey D', 'ykułu 2019']
# 4908 ['Hawrań (, ', 'ckich Tatr']
# 5381 ['Holocen (z', 'zypisy \n\n ']
# 24 ['PATRZ Hoku', 'Katsushika']
# 20 ['PATRZ Hiro', 'shige Andō']
# 7105 ['Henri Berg', 'rli w 1941']
# 4716 ['Helen Adam', 'rli w 1968']
# 1864 ['Heurystyka', 'ogia nauki']
# 24224 ['Hawaje (, ', 'dnoczonych']
# 4787 [' – jeden z', 'goria:Kana']
# 5640 ['Publiusz E', 'arli w 138']
# 11187 [' Prehistor', 'rzne \n \n\n ']
# 85456 ['mały|Jeden', ', 1999.\n\n ']
# 5782 ['mały|Karta', 'kryminacja']
# 29 ['REDIRECTHe', 'ry Asquith']
# 7170 ['Hydra (łac', 'lation \n\n ']
# 2565 ['thumb|Popi', 'rli w 1982']
# 22 ['redirect H', 'narfjörður']
# 1398 ['Heimaey (V', 'antyckiego']
# 1947 ['thumb|Buki', 'Szczecinie']
# 9963 ['Hipoteza S', 'ingwistyka']
# 8540 ['Historia b', 'zypisy \n\n*']
# 9132 ['Habsburgow', 'ebook).\n\n ']
# 2853 ['Habeas Cor', 'zenia 1679']
# 1194 ['Habanera –', 'c na Kubie']
# 1093 ['Harlem – d', 'Manhattanu']
# 8136 ['Haakon VII', 'rli w 1957']
# 39357 ['thumb|290p', 'e wojskowe']
# 3239 ['thumb|150p', 'y szarpane']
# 685 ['thumb|Hasz', 'i ().\n\n\n\n ']
# 2786 ['Hathor (He', ' mitologii']
# 17939 ['Hatszepsut', ' (kobiety)']
# 36085 ['Hatteria, ', ' Australii']
# 7773 ['Hawaje (; ', 'okojnego\n!']
# 2816 ['Hawana ( l', ' Północnej']
# 2284 ['Haarlem (I', 'a Północna']
# 6644 ['Hormony (o', '09-21].\n\n ']
# 2146 ['Halldór Ki', 'rli w 1998']
# 13385 ['Historia m', 'ria sztuki']
# 9804 ['Hermann Ka', 'rli w 1962']
# 2107 ['Hydrazyna,', 'zki wodoru']
# 14 ['REDIRECT H', 'RECT Haker']
# 6850 ['Haker () –', ':Hakerstwo']
# 4367 ['Heinrich T', 'rli w 1985']
# 22 ['REDIRECT H', 'nrich Böll']
# 13091 ['Harmonia s', 'fonetyczne']
# 6537 ['Howard Car', 'w Londynie']
# 10891 ['thumb|240p', ' w Atenach']
# 144 ['Witamy na ', ' Highlight']
# 9693 ['Harry Edmu', 'rli w 1978']
# 3208 ['thumb|Mang', 'ria:Hentai']
# 9978 ['thumb|200p', 'opisami\n\n ']
# 2130 ['Szwecja je', 'we Szwecji']
# 666 ['Hierotopog', 'skinie.\n\n!']
# 5830 ['Hel (He, )', 'szlachetne']
# 2857 ['Hipoteza (', 'ria:Logika']
# 3510 ['thumb|400p', 'a egipskie']
# 20 ['REDIRECT K', 'alendarium']
# 9392 ['Historia I', 'server \n\n ']
# 24 ['REDIRECT S', 'żytny Rzym']
# 92 [' Heliogaba', 'ii Sewerów']
# 5483 ['thumb|Hipe', 'ia:Widżety']
# 19 ['REDIRECT H', 'Hiperłącze']
# 27 ['REDIRECT H', ' Internetu']
# 17616 ['Historia t', 'wa 2005\n\n ']
# 118601 ['Historia n', '09-20].\n\n ']
# 35733 ['thumb|Herb', 'y na Medal']
# 32 ['PATRZ Kale', 'orii nauki']
# 1803 ['thumb|400p', 'broń palna']
# 19 ['REDIRECT H', 'Hipertekst']
# 5221 ['thumb|200p', 'ia religii']
# 1589 ['CZy mitolo', '    Żaneta']
# 3883 ['thumb|240p', 'rli w 2000']
# 888 ['Herenia Et', ' III wieku']
# 2111 ['Henoteizm ', 'oria:Teizm']
# 51581 ['mały|300px', '-23].\n \n\n ']
# 714 ['Jeśli będz', 'lektronu).']
# 307 ['Hekto (h) ', ' jednostek']
# 755 ['right|100p', ' i symboli']
# 499 ['thumb|Hejn', 'ne\n*Hejnał']
# 589 [' Herzog – ', 'la Bellowa']
# 44 ['PATRZ List', 'mi okrętów']
# 273 [' Hesperos ', 'aczniająca']
# 13 ['REDIRECT r', 'IRECT rtęć']
# 728 ['thumb|200p', ' hebrajski']
# 65028 ['mały|Para ', 'goria:LGBT']
# 4545 ['Hermann Mi', 'rli w 1909']
# 16 ['REDIRECT A', 'CT Allosom']
# 1259 ['Hymn harce', 'erski hymn']
# 8572 ['mały|240px', 'Montmartre']
# 1816 ['Hymn (z gr', ' muzyczne)']
# 45 ['REDIRECT P', 'owstańcza)']
# 10760 ['thumb|Praw', ' Polona\n\n ']
# 569 ['Herenniusz', ' III wieku']
# 18 ['REDIRECT H', ' Honoriusz']
# 18 ['REDIRECT H', ' Hostylian']
# 834 ['Hostylian,', 'arli w 251']
# 891 ['Homilia (g', 'rgia Słowa']
# 2330 ['mały|Karta', ' Polona\n\n ']
# 5218 ['thumb|240p', 'lerykalizm']
# 1748 ['Hipokryzja', 'voir-vivre']
# 26 ['REDIRECT N', 'i Hikosaka']
# 550 ['Hebraizm –', 'i semickie']
# 3133 ['mały|240px', 'XVII wieku']
# 898 ['Halerz (ni', 'ria:Waluty']
# 10203 ['thumb|300p', 'dania krwi']
# 4756 ['thumb|212p', 'owe żelaza']
# 8 ['TAM Hafn', 'TAM Hafn']
# 22 ['TAM Holm (', 'erwiastek)']
# 126 [' HF (z ang', ' chemiczny']
# 20997 ['thumb|240p', 'y na Medal']
# 21307 ['mały|Huńsk', ' \n \n \n \n\n ']
# 6799 ['thumb|upri', 'zypisy \n\n ']
# 8673 ['thumb|300p', 'ezopotamii']
# 6883 ['Herb szlac', '.\n \n \n \n\n ']
# 6275 ['mały\nmały|', 'audyjskiej']
# 1322 ['Hidżra (z ', 'rzenia 622']
# 16 ['REDIRECT S', 'CT Seppuku']
# 13 ['REDIRECT H', 'IRECT Herc']
# 951 ['Herc (Hz) ', 'od nazwisk']
# 5281 ['Kalendariu', '\n \nSzkocja']
# 400 ['thumb|300p', 'rli w 1694']
# 1704 ['Dla Kazika', '2010 (CET)']
# 39 ['PATRZ Ludz', 'odporności']
# 17 ['PATRZ Hann', 'annibalian']
# 4615 ['mały|Grób ', 'rli w 1951']
# 7158 ['thumb|Mied', 'w 4 p.n.e.']
# 415 ['Horyzont g', 'konomiczna']
# 10101 ['thumb|upri', 'a:Inflacja']
# 5678 ['thumb|240p', 'rli w 1978']
# 7347 ['Hymn państ', 'e z muzyką']
# 6031 ['thumb|Port', 'rli w 1869']
# 693 ['Gminy i dz', ' Haan\n Han']
# 768 ['Henr (H) –', 'od nazwisk']
# 6478 ['Heroldia –', 'ublicznego']
# 294 ['Hans Gotla', 'ta śmierci']
# 1034 ['Harmonia –', 'zypisy \n\n*']
# 60963 ['mały|Flaga', ' Północnej']
# 1032 ['mały|Świni', 'i rolnicze']
# 18403 ['mały|280x2', 'rtembergii']
# 2826 ['Huneryk (u', ' w V wieku']
# 2643 ['Hilderyk (', 'arli w 533']
# 107 [' hybrydyza', 'kleinowych']
# 315 [' hindus – ', ' Przypisy ']
# 2348 ['Hefajstos ', 'a rzemiosł']
# 2434 ['Hermes ( H', 'e z Odysei']
# 8662 ['Hera ( Hēr', 'anki Zeusa']
# 991 ['Hypnos ( H', 'egoria:Sen']
# 30948 ['thumb|upri', 'askowicami']
# 17189 ['{{Władca i', ' krakowscy']
# 34510 ['thumb|Płyt', 'iowieczna)']
# 25 ['REDIRECT H', ' I Brodaty']
# 2412 ['Haskell – ', ' funkcyjne']
# 184 [' Ha – skró', 'audyjskiej']
# 3550 ['Trochę mni', 'encji GPL.']
# 5208 [' lata 60. ', 'gramowania']
# 598 ['thumb|Prep', 'zypisy \n\n ']
# 8047 ['Polskie pi', 'e z muzyką']
# 3087 ['Implikacja', 'hunek zdań']
# 9300 ['Indukcja m', '03-19].\n\n ']
# 158453 ['thumb|239x', 'ycy.org\n\n ']
# 6626 ['thumb|upri', 'ebsite \n\n ']
# 1644 ['Izomeria o', ', izomeria']
# 1545 ['Izomeria –', 'icznych\n\n ']
# 31 ['REDIRECT I', 'stytucyjna']
# 5249 ['thumb|250p', 'rzne \n \n\n ']
# 2915 ['Interpolac', 'omputerowa']
# 2786 ['Interlinia', 'egoria:DTP']
# 30 ['REDIRECT I', 'ometryczna']
# 5995 ['IOCCC () –', 'ormatyczne']
# 562 ['IRIX – sys', 'goria:Unix']
# 52143 ['Islandia (', ' nordyckie']
# 5251 ['Imię () – ', 'e Name \n\n ']
# 1083 ['Imiona sem', ' Biblii\n\n ']
# 17722 ['Imiona sło', 'osobowe\n\n ']
# 70196 ['thumb|Szah', 'al data\n\n ']
# 14867 ['IPv6 () – ', ' Force)\n\n ']
# 3705 ['Dostawca u', 'a:Internet']
# 1136 ['thumb|245p', 'yczne Azji']
# 3936 ['thumb|240p', 'ieciarstwo']
# 1932 ['Iglice () ', 'ria:Iglice']
# 303 [' Technika ', 's tekstowy']
# 50 ['redirect M', 'alizacyjna']
# 3772 ['thumb|240p', 'z. 111)\n\n ']

# %% [markdown]
# ## Split into words

# %%
re_word = re.compile(r"\b(\w{2,})\b(?!\. ?\d)", re.I | re.U | re.M)
re_digit = re.compile(r"[\d_]")

def split_words(text):
    for m in re_word.finditer(text):
        word = m[0]
        if not re_digit.search(word):
            yield word.lower()

# %%
list(split_words("Lorem ipsum abc123 dolor sit amet?"))
# Out:
# ['lorem', 'ipsum', 'dolor', 'sit', 'amet']

# %% [markdown]
# ## Count most common words

# %%
from collections import Counter

word_counter = Counter()

def count_words_in_text(text):
    word_counter.update(split_words(text))

parser = MultiDocumentParser(count_words_in_text, WikipediaHandler)
for file_name in FILENAMES:
    read_chunks(file_name, parser.feed, chunk_size, 3)
# Out:
# Chunk 1 of 8388608 bytes <class 'str'>
# Parser reset
# Chunk 2 of 8388608 bytes <class 'str'>
# Chunk 3 of 8388608 bytes <class 'str'>

# %%
print("Most common words in Polish Wikipedia:")
print(word_counter.most_common(50))
# Out:
# Most common words in Polish Wikipedia:
# [('na', 26592), ('się', 22263), ('do', 19682), ('jest', 12148), ('nie', 9211), ('przez', 8263), ('od', 7875), ('roku', 7496), ('to', 7398), ('oraz', 6285), ('że', 6142), ('po', 5724), ('kategoria', 5509), ('jako', 4697), ('za', 4570), ('są', 4462), ('dla', 4354), ('jego', 4195), ('lub', 3804), ('jak', 3546), ('tym', 3425), ('był', 3099), ('pod', 3072), ('także', 3028), ('ze', 2931), ('co', 2888), ('też', 2781), ('thumb', 2696), ('jednak', 2623), ('który', 2558), ('które', 2415), ('wieku', 2397), ('ich', 2331), ('tego', 2291), ('jej', 2269), ('również', 2268), ('np', 2175), ('in', 2151), ('został', 2115), ('przy', 2096), ('the', 2001), ('czy', 1986), ('ii', 1950), ('była', 1884), ('latach', 1868), ('ma', 1851), ('miasta', 1783), ('ale', 1777), ('lat', 1696), ('być', 1655)]

# %% [markdown]
# ## Compare it with the NLTK build-in corpus of the Polish language of the 1960s

# %%
import nltk
from nltk.corpus.reader import pl196x

def pl196x_words():
    pl196x_dir = nltk.data.find("corpora/pl196x")
    pl = pl196x.Pl196xCorpusReader(pl196x_dir, r".*\.xml", textids="textids.txt", cat_file="cats.txt")
    return pl.words(fileids=pl.fileids(), categories="cats.txt")

def pl196x_words_filtered():
    for word in pl196x_words():
        if re_word.match(word) and not re_digit.search(word):
            yield word.lower()

# %%
word_counter = Counter()  # reset counter
word_counter.update(pl196x_words_filtered())
print("Most common words in PL196x corpus:")
print(word_counter.most_common(50))
# Out:
# Most common words in PL196x corpus:
# [('się', 10315), ('nie', 9460), ('na', 9285), ('do', 6260), ('to', 6186), ('że', 4704), ('jest', 3541), ('jak', 2882), ('co', 2449), ('ale', 2228), ('tak', 2210), ('po', 1898), ('od', 1883), ('tym', 1851), ('już', 1831), ('za', 1548), ('przez', 1535), ('tylko', 1496), ('dla', 1450), ('tego', 1339), ('ja', 1312), ('czy', 1240), ('pan', 1189), ('mnie', 1155), ('jeszcze', 1140), ('są', 1112), ('może', 1090), ('przy', 1064), ('ze', 999), ('mi', 941), ('ten', 939), ('roku', 928), ('jego', 915), ('było', 893), ('bo', 884), ('będzie', 883), ('tu', 883), ('ich', 860), ('tej', 827), ('sobie', 816), ('ma', 812), ('bardzo', 789), ('go', 779), ('oraz', 778), ('tysiąc', 772), ('więc', 752), ('które', 750), ('no', 745), ('tych', 741), ('był', 736)]

# %% [markdown]
# ## Count it as grammatical lemmas

# %%
import morfeusz2
morf = morfeusz2.Morfeusz()

# %%
morf.analyse("miał")
# Out:
# [(0, 1, ('miał', 'miał', 'subst:sg:nom.acc:m3', ['nazwa_pospolita'], [])),
#  (0, 1, ('miał', 'mieć', 'praet:sg:m1.m2.m3:imperf', [], []))]

# %%
def lemma(word):
    if word == 'miał':
        return 'mieć'
    a = morf.analyse(word)
    return a[0][2][1]

[lemma('miał'), lemma('chciał'), lemma('roku')]
# Out:
# ['mieć', 'chcieć', 'rok:Sm3~lata']

# %%
def lemma(word):
    if word == 'miał':
        return 'mieć'
    a = morf.analyse(word)
    return a[0][2][1].split(':')[0]

[lemma('miał'), lemma('chciał'), lemma('roku')]
# Out:
# ['mieć', 'chcieć', 'rok']

# %%
word_counter = Counter()  # reset counter
word_counter.update(map(lemma, pl196x_words_filtered()))

print("Most common lemmas in PL196x corpus:")
print(word_counter.most_common(50))
# Out:
# Most common lemmas in PL196x corpus:
# [('ten', 11460), ('się', 10315), ('nie', 9808), ('na', 9768), ('być', 9079), ('do', 6312), ('on', 5444), ('że', 4752), ('co', 3362), ('który', 3171), ('jak', 3002), ('ja', 2374), ('tak', 2250), ('ale', 2232), ('po', 2156), ('oda', 2034), ('tym', 1852), ('już', 1833), ('pan', 1752), ('za', 1719), ('przez', 1554), ('czy', 1499), ('tylko', 1498), ('taki', 1475), ('dla', 1453), ('tysiąc', 1373), ('mój', 1291), ('siebie', 1269), ('bardzo', 1211), ('mieć', 1188), ('swój', 1175), ('móc', 1175), ('wiedzieć', 1159), ('miąć', 1157), ('jeszcze', 1142), ('rok', 1121), ('ty', 1107), ('może', 1090), ('sam', 1086), ('wszystek', 1084), ('pani', 1084), ('przy', 1064), ('dwa', 1038), ('czas', 1024), ('mówić', 1016), ('z', 1002), ('inny', 995), ('chcieć', 994), ('my', 974), ('człowiek', 960)]

# %%
def count_lemmas_in_text(text):
    word_counter.update(map(lemma, split_words(text)))

word_counter = Counter()  # reset counter
parser = MultiDocumentParser(count_lemmas_in_text, WikipediaHandler)
for file_name in FILENAMES:
    read_chunks(file_name, parser.feed, chunk_size, 3)

print("Most common lemmas in Polish Wikipedia:")
print(word_counter.most_common(50))
# Out:
# Chunk 1 of 8388608 bytes <class 'str'>
# New XML document - parser reset
# Chunk 2 of 8388608 bytes <class 'str'>
# Chunk 3 of 8388608 bytes <class 'str'>
# Most common lemmas in Polish Wikipedia:
# [('na', 26598), ('być', 23535), ('się', 22263), ('do', 19687), ('ten', 15923), ('on', 13830), ('który', 11639), ('nie', 9211), ('przez', 8287), ('rok', 8205), ('oda', 7898), ('oraz', 6285), ('że', 6149), ('kategoria', 5731), ('po', 5724), ('zostać', 4972), ('jako', 4697), ('za', 4572), ('dla', 4358), ('lato', 4223), ('polski', 4138), ('inny', 3937), ('lub', 3804), ('co', 3572), ('jak', 3548), ('miasto', 3484), ('tym', 3425), ('czas', 3208), ('swój', 3101), ('pod', 3073), ('także', 3028), ('pierwszy', 2990), ('z', 2935), ('wiek', 2855), ('też', 2781), ('wielki', 2745), ('thumb', 2696), ('jednak', 2623), ('sam', 2419), ('czy', 2415), ('język', 2302), ('mieć', 2281), ('jej', 2269), ('również', 2268), ('część', 2212), ('jeden', 2204), ('np', 2175), ('mały', 2172), ('bardzo', 2171), ('in', 2151)]
